# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../../down_stream_dataset/oppo_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (2730, 3, 300), Train label shape: (2730,)
# Valid data shape: (683, 3, 300), Valid label shape: (683,)
# Test data shape: (854, 3, 300), Test label shape: (854,)
# Scaled Train data shape: (2730, 3, 300)
# Scaled Valid data shape: (683, 3, 300)
# Scaled Test data shape: (854, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 0    1477
# 3     578
# 1     554
# 2     121
# dtype: int64
# 0    472
# 1    194
# 3    150
# 2     38
# dtype: int64
# 0    367
# 3    162
# 1    133
# 2     21
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
model.to(device)
# Out:
# 4
# LinearAttentionTransformerLM(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=768, out_features=768, bias=True)
# )

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=768, out_features=768, bias=True)
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
# state_dict

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_oppo_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_80914/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 0.9045, valid Loss: 0.7250484390692278, Accuracy: 63.99%, Val Accuracy: 70.57%
# Epoch 2/100, Loss: 0.7749, valid Loss: 0.685330867767334, Accuracy: 69.05%, Val Accuracy: 72.77%
# Epoch 3/100, Loss: 0.7419, valid Loss: 0.6973419081081044, Accuracy: 70.26%, Val Accuracy: 73.06%
# Epoch 4/100, Loss: 0.7273, valid Loss: 0.6721872633153742, Accuracy: 70.15%, Val Accuracy: 72.18%
# Epoch 5/100, Loss: 0.7111, valid Loss: 0.6447532935576006, Accuracy: 70.84%, Val Accuracy: 73.35%
# Epoch 6/100, Loss: 0.6896, valid Loss: 0.6417820291085676, Accuracy: 71.65%, Val Accuracy: 73.79%
# Epoch 7/100, Loss: 0.6880, valid Loss: 0.6557297327301719, Accuracy: 71.94%, Val Accuracy: 71.89%
# Epoch 8/100, Loss: 0.6650, valid Loss: 0.6351709582588889, Accuracy: 72.67%, Val Accuracy: 73.35%
# Epoch 9/100, Loss: 0.6380, valid Loss: 0.6211970773610201, Accuracy: 73.81%, Val Accuracy: 73.65%
# Epoch 10/100, Loss: 0.6321, valid Loss: 0.6439474008300088, Accuracy: 73.88%, Val Accuracy: 69.25%
# Epoch 11/100, Loss: 0.6156, valid Loss: 0.5991325703534213, Accuracy: 74.98%, Val Accuracy: 74.96%
# Epoch 12/100, Loss: 0.5925, valid Loss: 0.6320277018980547, Accuracy: 76.15%, Val Accuracy: 72.18%
# Epoch 13/100, Loss: 0.5774, valid Loss: 0.6401237791234796, Accuracy: 76.19%, Val Accuracy: 72.47%
# Epoch 14/100, Loss: 0.5667, valid Loss: 0.6112876534461975, Accuracy: 77.95%, Val Accuracy: 74.82%
# Epoch 15/100, Loss: 0.5554, valid Loss: 0.6097801707007668, Accuracy: 77.33%, Val Accuracy: 73.21%
# Epoch 16/100, Loss: 0.5124, valid Loss: 0.625113386999477, Accuracy: 79.30%, Val Accuracy: 71.01%
# Epoch 17/100, Loss: 0.5112, valid Loss: 0.6053574139421637, Accuracy: 79.56%, Val Accuracy: 75.40%
# Epoch 18/100, Loss: 0.4823, valid Loss: 0.6061935939572074, Accuracy: 81.10%, Val Accuracy: 74.67%
# Epoch 19/100, Loss: 0.4646, valid Loss: 0.6267413334413008, Accuracy: 81.17%, Val Accuracy: 75.11%
# Epoch 20/100, Loss: 0.4403, valid Loss: 0.6183940659869801, Accuracy: 81.79%, Val Accuracy: 74.38%
# Epoch 21/100, Loss: 0.4168, valid Loss: 0.6421949511224573, Accuracy: 83.22%, Val Accuracy: 75.11%
# Epoch 22/100, Loss: 0.3891, valid Loss: 0.6769276884469119, Accuracy: 84.32%, Val Accuracy: 72.62%
# Epoch 23/100, Loss: 0.3906, valid Loss: 0.6734018244526603, Accuracy: 84.69%, Val Accuracy: 75.40%
# Epoch 24/100, Loss: 0.3410, valid Loss: 0.6571421650323, Accuracy: 87.25%, Val Accuracy: 72.62%
# Epoch 25/100, Loss: 0.3478, valid Loss: 0.7070469368587841, Accuracy: 86.45%, Val Accuracy: 73.06%
# Epoch 26/100, Loss: 0.3268, valid Loss: 0.717142178253694, Accuracy: 86.85%, Val Accuracy: 73.50%
# Epoch 27/100, Loss: 0.3166, valid Loss: 0.7803925384174694, Accuracy: 87.11%, Val Accuracy: 76.28%
# Epoch 28/100, Loss: 0.2565, valid Loss: 0.7581572451374747, Accuracy: 90.18%, Val Accuracy: 74.82%
# Epoch 29/100, Loss: 0.2442, valid Loss: 0.8218805410645225, Accuracy: 90.15%, Val Accuracy: 75.11%
# Epoch 30/100, Loss: 0.2330, valid Loss: 0.8063950430263173, Accuracy: 91.28%, Val Accuracy: 73.65%
# Epoch 31/100, Loss: 0.1977, valid Loss: 0.8745302612131293, Accuracy: 92.42%, Val Accuracy: 71.30%
# Epoch 32/100, Loss: 0.2180, valid Loss: 0.9148437434976752, Accuracy: 91.54%, Val Accuracy: 74.67%
# Epoch 33/100, Loss: 0.1993, valid Loss: 0.8997491489757191, Accuracy: 92.56%, Val Accuracy: 71.89%
# Epoch 34/100, Loss: 0.1924, valid Loss: 1.0173314755613154, Accuracy: 92.86%, Val Accuracy: 72.18%
# Epoch 35/100, Loss: 0.1617, valid Loss: 0.9847664128650319, Accuracy: 94.32%, Val Accuracy: 73.65%
# Epoch 36/100, Loss: 0.1302, valid Loss: 1.1006383950060064, Accuracy: 95.24%, Val Accuracy: 72.77%
# Epoch 37/100, Loss: 0.1321, valid Loss: 1.061367923563177, Accuracy: 94.51%, Val Accuracy: 73.79%
# Epoch 38/100, Loss: 0.1397, valid Loss: 1.1067856821146878, Accuracy: 94.87%, Val Accuracy: 73.06%
# Epoch 39/100, Loss: 0.0965, valid Loss: 1.280584221536463, Accuracy: 96.59%, Val Accuracy: 73.06%
# Epoch 40/100, Loss: 0.1067, valid Loss: 1.320010076869618, Accuracy: 95.75%, Val Accuracy: 71.30%
# Epoch 41/100, Loss: 0.1622, valid Loss: 1.1110621528192, Accuracy: 94.03%, Val Accuracy: 70.86%
# Epoch 42/100, Loss: 0.0869, valid Loss: 1.243036232211373, Accuracy: 96.81%, Val Accuracy: 73.79%
# Epoch 43/100, Loss: 0.0739, valid Loss: 1.4009845148433338, Accuracy: 97.44%, Val Accuracy: 74.08%
# Epoch 44/100, Loss: 0.1054, valid Loss: 1.337679472836581, Accuracy: 96.37%, Val Accuracy: 73.21%
# Epoch 45/100, Loss: 0.0981, valid Loss: 1.315848637710918, Accuracy: 96.78%, Val Accuracy: 73.79%
# Epoch 46/100, Loss: 0.0818, valid Loss: 1.2798158851536838, Accuracy: 97.25%, Val Accuracy: 74.67%
# Epoch 47/100, Loss: 0.0833, valid Loss: 1.4485034238208423, Accuracy: 97.07%, Val Accuracy: 73.50%
# Epoch 48/100, Loss: 0.1049, valid Loss: 1.3016183105382053, Accuracy: 96.52%, Val Accuracy: 71.01%
# Epoch 49/100, Loss: 0.0529, valid Loss: 1.425265442241322, Accuracy: 97.99%, Val Accuracy: 73.94%
# Epoch 50/100, Loss: 0.0613, valid Loss: 1.3907424861734563, Accuracy: 97.88%, Val Accuracy: 73.50%
# Epoch 51/100, Loss: 0.0652, valid Loss: 1.3990499485622754, Accuracy: 97.95%, Val Accuracy: 73.94%
# Epoch 52/100, Loss: 0.0561, valid Loss: 1.4817229997028003, Accuracy: 98.28%, Val Accuracy: 73.65%
# Epoch 53/100, Loss: 0.0570, valid Loss: 1.5342902920462869, Accuracy: 97.91%, Val Accuracy: 73.06%
# Epoch 54/100, Loss: 0.0773, valid Loss: 1.4191064563664524, Accuracy: 97.14%, Val Accuracy: 72.77%
# Epoch 55/100, Loss: 0.0768, valid Loss: 1.4590227983214639, Accuracy: 97.29%, Val Accuracy: 72.91%
# Epoch 56/100, Loss: 0.0767, valid Loss: 1.4924890995025635, Accuracy: 97.84%, Val Accuracy: 73.21%
# Epoch 57/100, Loss: 0.0428, valid Loss: 1.5863734808835117, Accuracy: 98.61%, Val Accuracy: 72.91%
# Epoch 58/100, Loss: 0.0293, valid Loss: 1.6972377842122859, Accuracy: 98.97%, Val Accuracy: 73.94%
# Epoch 59/100, Loss: 0.0447, valid Loss: 1.6985752745108171, Accuracy: 98.46%, Val Accuracy: 72.62%
# Epoch 60/100, Loss: 0.0791, valid Loss: 1.3989466537128796, Accuracy: 97.40%, Val Accuracy: 74.82%
# Epoch 61/100, Loss: 0.0599, valid Loss: 1.5304244377396323, Accuracy: 97.91%, Val Accuracy: 72.04%
# Epoch 62/100, Loss: 0.0350, valid Loss: 1.7231702154332942, Accuracy: 98.75%, Val Accuracy: 73.35%
# Epoch 63/100, Loss: 0.0427, valid Loss: 1.5754485888914629, Accuracy: 98.46%, Val Accuracy: 74.08%
# Epoch 64/100, Loss: 0.0414, valid Loss: 1.7075033892284741, Accuracy: 98.79%, Val Accuracy: 74.08%
# Epoch 65/100, Loss: 0.0452, valid Loss: 1.4804247238419272, Accuracy: 98.61%, Val Accuracy: 73.50%
# Epoch 66/100, Loss: 0.0246, valid Loss: 1.676383983005177, Accuracy: 99.19%, Val Accuracy: 74.82%
# Epoch 67/100, Loss: 0.0223, valid Loss: 1.7670944387262517, Accuracy: 99.16%, Val Accuracy: 72.47%
# Epoch 68/100, Loss: 0.0208, valid Loss: 1.7360003265467556, Accuracy: 99.52%, Val Accuracy: 72.91%
# Epoch 69/100, Loss: 0.0181, valid Loss: 1.9289178198034114, Accuracy: 99.41%, Val Accuracy: 73.79%
# Epoch 70/100, Loss: 0.0177, valid Loss: 2.020242290063338, Accuracy: 99.38%, Val Accuracy: 70.28%
# Epoch 71/100, Loss: 0.0470, valid Loss: 1.5847670869393782, Accuracy: 98.53%, Val Accuracy: 73.06%
# Epoch 72/100, Loss: 0.0209, valid Loss: 2.0297687270424585, Accuracy: 99.34%, Val Accuracy: 73.35%
# Epoch 73/100, Loss: 0.0201, valid Loss: 2.030774409120733, Accuracy: 99.30%, Val Accuracy: 69.84%
# Epoch 74/100, Loss: 0.0587, valid Loss: 1.5975662903352217, Accuracy: 98.21%, Val Accuracy: 73.65%
# Epoch 75/100, Loss: 0.0904, valid Loss: 1.5576112161983142, Accuracy: 96.85%, Val Accuracy: 71.45%
# Epoch 76/100, Loss: 0.0723, valid Loss: 1.633283625949513, Accuracy: 97.40%, Val Accuracy: 72.91%
# Epoch 77/100, Loss: 0.0509, valid Loss: 1.7227961691943081, Accuracy: 98.46%, Val Accuracy: 71.01%
# Epoch 78/100, Loss: 0.0261, valid Loss: 1.9363585060293025, Accuracy: 99.27%, Val Accuracy: 72.62%
# Epoch 79/100, Loss: 0.0385, valid Loss: 1.5789846073497424, Accuracy: 98.94%, Val Accuracy: 72.18%
# Epoch 80/100, Loss: 0.0174, valid Loss: 1.7262169501998208, Accuracy: 99.45%, Val Accuracy: 69.99%
# Epoch 81/100, Loss: 0.0266, valid Loss: 1.7312889911911704, Accuracy: 99.38%, Val Accuracy: 72.77%
# Epoch 82/100, Loss: 0.0154, valid Loss: 1.7612877108834006, Accuracy: 99.49%, Val Accuracy: 74.23%
# Epoch 83/100, Loss: 0.0042, valid Loss: 1.9582870277491482, Accuracy: 99.85%, Val Accuracy: 74.23%
# Epoch 84/100, Loss: 0.0023, valid Loss: 1.9983798265457153, Accuracy: 99.93%, Val Accuracy: 74.67%
# Epoch 85/100, Loss: 0.0016, valid Loss: 2.101019577546553, Accuracy: 99.93%, Val Accuracy: 72.91%
# Epoch 86/100, Loss: 0.0006, valid Loss: 2.155661095272411, Accuracy: 100.00%, Val Accuracy: 73.35%
# Epoch 87/100, Loss: 0.0004, valid Loss: 2.180841706015847, Accuracy: 100.00%, Val Accuracy: 73.21%
# Epoch 88/100, Loss: 0.0003, valid Loss: 2.205602288246155, Accuracy: 100.00%, Val Accuracy: 73.21%
# Epoch 89/100, Loss: 0.0002, valid Loss: 2.2414860183542427, Accuracy: 100.00%, Val Accuracy: 73.50%
# Epoch 90/100, Loss: 0.0002, valid Loss: 2.2611651962453667, Accuracy: 100.00%, Val Accuracy: 73.21%
# Epoch 91/100, Loss: 0.0002, valid Loss: 2.2851645187898115, Accuracy: 100.00%, Val Accuracy: 73.65%
# Epoch 92/100, Loss: 0.0001, valid Loss: 2.3059991489757192, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 93/100, Loss: 0.0001, valid Loss: 2.3291202891956675, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 94/100, Loss: 0.0001, valid Loss: 2.3420545187863437, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 95/100, Loss: 0.0001, valid Loss: 2.3562467748468574, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 96/100, Loss: 0.0001, valid Loss: 2.369476545940746, Accuracy: 100.00%, Val Accuracy: 73.21%
# Epoch 97/100, Loss: 0.0001, valid Loss: 2.383215535770763, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 98/100, Loss: 0.0001, valid Loss: 2.3962653441862627, Accuracy: 100.00%, Val Accuracy: 73.21%
# Epoch 99/100, Loss: 0.0001, valid Loss: 2.4104150208559902, Accuracy: 100.00%, Val Accuracy: 73.06%
# Epoch 100/100, Loss: 0.0001, valid Loss: 2.422011071985418, Accuracy: 100.00%, Val Accuracy: 72.91%
# Best model reloaded with valid loss:  0.5991325703534213   time: 11

# %%
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# Best model reloaded with valid loss:  0.5991325703534213   time: 11

# %%
# val_loss = []
# for i in range(num_epochs):
#     value = validation_losses[i].item()
#     val_loss.append(value)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
ax.set_ylim(0.0, 2.5)
ax2.set_ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = train_model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_80914/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 72.014%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.700     0.919     0.795       472
#            1      0.671     0.253     0.367       194
#            2      0.875     0.368     0.519        38
#            3      0.814     0.787     0.800       150
#
#     accuracy                          0.720       854
#    macro avg      0.765     0.582     0.620       854
# weighted avg      0.721     0.720     0.686       854

# %%
val_mean = sum(validation_losses)/100
val_max = max(validation_losses)
val_min = min(validation_losses)

first = validation_losses[0]
end = validation_losses[99]
print("mean  ",val_mean)
print("max   ", val_max)
print("min   ", val_min)
print("first ", first)
print("end   ", end)
# Out:
# mean   1.3775802644816313
# max    2.422011071985418
# min    0.5991325703534213
# first  0.7250484390692278
# end    2.422011071985418
