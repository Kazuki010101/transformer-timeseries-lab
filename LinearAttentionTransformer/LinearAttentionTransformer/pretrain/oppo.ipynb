# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../down_stream_dataset/oppo_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (2730, 3, 300), Train label shape: (2730,)
# Valid data shape: (683, 3, 300), Valid label shape: (683,)
# Test data shape: (854, 3, 300), Test label shape: (854,)
# Scaled Train data shape: (2730, 3, 300)
# Scaled Valid data shape: (683, 3, 300)
# Scaled Test data shape: (854, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 0    1477
# 3     578
# 1     554
# 2     121
# dtype: int64
# 0    472
# 1    194
# 3    150
# 2     38
# dtype: int64
# 0    367
# 3    162
# 1    133
# 2     21
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
state_dict = torch.load('path/pretrained_1/5_4pretrain_model_predict.pth')

# キー名の修正
new_state_dict = {}
for key, value in state_dict.items():
    new_key = key.replace("weights_", "weights.")  # キー名の変更
    new_state_dict[new_key] = value

# 修正済みの重みをモデルにロード
model.load_state_dict(new_state_dict, strict=True)
model.to(device)
# Out:
# 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 41
#      38     new_state_dict[new_key] = value
#      40 # 修正済みの重みをモデルにロード
# ---> 41 model.load_state_dict(new_state_dict, strict=True)
#      42 model.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LinearAttentionTransformerLM:
# 	Unexpected key(s) in state_dict: "out.weight", "out.bias", "predict.weight", "predict.bias".

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-5)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_oppo_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_129659/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 0.9509, valid Loss: 0.7608422636985779, Accuracy: 62.75%, Val Accuracy: 71.30%
# Epoch 2/100, Loss: 0.8045, valid Loss: 0.7306237491694364, Accuracy: 68.42%, Val Accuracy: 71.01%
# Epoch 3/100, Loss: 0.7827, valid Loss: 0.7062742926857688, Accuracy: 68.75%, Val Accuracy: 70.86%
# Epoch 4/100, Loss: 0.7587, valid Loss: 0.6840805411338806, Accuracy: 69.12%, Val Accuracy: 71.30%
# Epoch 5/100, Loss: 0.7367, valid Loss: 0.6693213365294717, Accuracy: 69.49%, Val Accuracy: 71.45%
# Epoch 6/100, Loss: 0.7172, valid Loss: 0.6560280431400646, Accuracy: 70.26%, Val Accuracy: 71.89%
# Epoch 7/100, Loss: 0.6974, valid Loss: 0.6554627635262229, Accuracy: 71.65%, Val Accuracy: 72.77%
# Epoch 8/100, Loss: 0.6794, valid Loss: 0.6278809905052185, Accuracy: 72.49%, Val Accuracy: 72.77%
# Epoch 9/100, Loss: 0.6605, valid Loss: 0.6368792707269842, Accuracy: 73.55%, Val Accuracy: 73.21%
# Epoch 10/100, Loss: 0.6394, valid Loss: 0.6310951709747314, Accuracy: 73.96%, Val Accuracy: 73.50%
# Epoch 11/100, Loss: 0.6269, valid Loss: 0.621602323922244, Accuracy: 74.87%, Val Accuracy: 74.38%
# Epoch 12/100, Loss: 0.6094, valid Loss: 0.6150915297594938, Accuracy: 75.46%, Val Accuracy: 74.23%
# Epoch 13/100, Loss: 0.5815, valid Loss: 0.6009235246614977, Accuracy: 77.11%, Val Accuracy: 73.35%
# Epoch 14/100, Loss: 0.5666, valid Loss: 0.6027281473983418, Accuracy: 77.40%, Val Accuracy: 72.77%
# Epoch 15/100, Loss: 0.5516, valid Loss: 0.5836492451754484, Accuracy: 78.53%, Val Accuracy: 73.79%
# Epoch 16/100, Loss: 0.5290, valid Loss: 0.6030158617279746, Accuracy: 78.61%, Val Accuracy: 74.23%
# Epoch 17/100, Loss: 0.5139, valid Loss: 0.6567476012490012, Accuracy: 79.56%, Val Accuracy: 73.94%
# Epoch 18/100, Loss: 0.5081, valid Loss: 0.6017873558131132, Accuracy: 80.00%, Val Accuracy: 74.96%
# Epoch 19/100, Loss: 0.4830, valid Loss: 0.6455141468481584, Accuracy: 81.36%, Val Accuracy: 73.50%
# Epoch 20/100, Loss: 0.4809, valid Loss: 0.6049832268194719, Accuracy: 81.17%, Val Accuracy: 74.52%
# Epoch 21/100, Loss: 0.4358, valid Loss: 0.6153694933111017, Accuracy: 83.85%, Val Accuracy: 74.23%
# Epoch 22/100, Loss: 0.4276, valid Loss: 0.6152827306227251, Accuracy: 83.48%, Val Accuracy: 70.13%
# Epoch 23/100, Loss: 0.4058, valid Loss: 0.6316548911007968, Accuracy: 85.90%, Val Accuracy: 70.57%
# Epoch 24/100, Loss: 0.3844, valid Loss: 0.6235732544552196, Accuracy: 86.37%, Val Accuracy: 72.62%
# Epoch 25/100, Loss: 0.3621, valid Loss: 0.6453193697062406, Accuracy: 86.89%, Val Accuracy: 72.04%
# Epoch 26/100, Loss: 0.3566, valid Loss: 0.6985628604888916, Accuracy: 87.03%, Val Accuracy: 68.08%
# Epoch 27/100, Loss: 0.3675, valid Loss: 0.6712849627841603, Accuracy: 86.23%, Val Accuracy: 73.79%
# Epoch 28/100, Loss: 0.3209, valid Loss: 0.6696699640967629, Accuracy: 89.16%, Val Accuracy: 71.30%
# Epoch 29/100, Loss: 0.3099, valid Loss: 0.7386425571008162, Accuracy: 88.46%, Val Accuracy: 73.35%
# Epoch 30/100, Loss: 0.2918, valid Loss: 0.6843824494968761, Accuracy: 89.67%, Val Accuracy: 71.01%
# Epoch 31/100, Loss: 0.2762, valid Loss: 0.6898265535181219, Accuracy: 90.66%, Val Accuracy: 72.77%
# Epoch 32/100, Loss: 0.2497, valid Loss: 0.722140290520408, Accuracy: 91.83%, Val Accuracy: 70.86%
# Epoch 33/100, Loss: 0.2385, valid Loss: 0.7178777347911488, Accuracy: 92.71%, Val Accuracy: 72.18%
# Epoch 34/100, Loss: 0.2011, valid Loss: 0.783007182858207, Accuracy: 94.40%, Val Accuracy: 71.45%
# Epoch 35/100, Loss: 0.1837, valid Loss: 0.8088443766940724, Accuracy: 94.58%, Val Accuracy: 69.99%
# Epoch 36/100, Loss: 0.2099, valid Loss: 0.7848070697350935, Accuracy: 92.75%, Val Accuracy: 70.13%
# Epoch 37/100, Loss: 0.1684, valid Loss: 0.8199087489734996, Accuracy: 95.09%, Val Accuracy: 68.81%
# Epoch 38/100, Loss: 0.1386, valid Loss: 0.8418736078522422, Accuracy: 96.70%, Val Accuracy: 72.47%
# Epoch 39/100, Loss: 0.1355, valid Loss: 1.0035809386860242, Accuracy: 96.48%, Val Accuracy: 73.94%
# Epoch 40/100, Loss: 0.1656, valid Loss: 0.8867627273906361, Accuracy: 94.87%, Val Accuracy: 72.47%
# Epoch 41/100, Loss: 0.1245, valid Loss: 0.8683507605032488, Accuracy: 96.85%, Val Accuracy: 69.11%
# Epoch 42/100, Loss: 0.1054, valid Loss: 0.9064107645641674, Accuracy: 97.66%, Val Accuracy: 71.45%
# Epoch 43/100, Loss: 0.0836, valid Loss: 0.9232801740819757, Accuracy: 98.24%, Val Accuracy: 70.28%
# Epoch 44/100, Loss: 0.1051, valid Loss: 1.0147209546782754, Accuracy: 97.11%, Val Accuracy: 72.62%
# Epoch 45/100, Loss: 0.1075, valid Loss: 0.9969115040519021, Accuracy: 96.74%, Val Accuracy: 72.18%
# Epoch 46/100, Loss: 0.0707, valid Loss: 1.0719797557050532, Accuracy: 98.64%, Val Accuracy: 73.65%
# Epoch 47/100, Loss: 0.0888, valid Loss: 1.0029825622385198, Accuracy: 97.33%, Val Accuracy: 70.57%
# Epoch 48/100, Loss: 0.0769, valid Loss: 0.9972886443138123, Accuracy: 98.06%, Val Accuracy: 70.42%
# Epoch 49/100, Loss: 0.0477, valid Loss: 1.115376434542916, Accuracy: 99.27%, Val Accuracy: 71.74%
# Epoch 50/100, Loss: 0.0450, valid Loss: 1.1502582159909336, Accuracy: 99.27%, Val Accuracy: 74.08%
# Epoch 51/100, Loss: 0.0358, valid Loss: 1.1286138621243564, Accuracy: 99.41%, Val Accuracy: 73.06%
# Epoch 52/100, Loss: 0.0298, valid Loss: 1.2456787716258655, Accuracy: 99.45%, Val Accuracy: 74.08%
# Epoch 53/100, Loss: 0.0595, valid Loss: 1.0285680294036865, Accuracy: 98.50%, Val Accuracy: 72.18%
# Epoch 54/100, Loss: 0.0543, valid Loss: 1.220819890499115, Accuracy: 98.72%, Val Accuracy: 71.45%
# Epoch 55/100, Loss: 0.0345, valid Loss: 1.17233299667185, Accuracy: 99.38%, Val Accuracy: 70.86%
# Epoch 56/100, Loss: 0.0222, valid Loss: 1.2160124074329028, Accuracy: 99.71%, Val Accuracy: 72.33%
# Epoch 57/100, Loss: 0.0278, valid Loss: 1.2545188069343567, Accuracy: 99.41%, Val Accuracy: 69.11%
# Epoch 58/100, Loss: 0.0420, valid Loss: 1.2372209375554866, Accuracy: 98.86%, Val Accuracy: 69.11%
# Epoch 59/100, Loss: 0.0277, valid Loss: 1.2233621640638872, Accuracy: 99.38%, Val Accuracy: 72.18%
# Epoch 60/100, Loss: 0.0266, valid Loss: 1.2881269671700217, Accuracy: 99.41%, Val Accuracy: 72.18%
# Epoch 61/100, Loss: 0.0151, valid Loss: 1.2579555023800244, Accuracy: 99.85%, Val Accuracy: 70.13%
# Epoch 62/100, Loss: 0.0170, valid Loss: 1.351870601827448, Accuracy: 99.67%, Val Accuracy: 70.86%
# Epoch 63/100, Loss: 0.0231, valid Loss: 1.2844748226079075, Accuracy: 99.56%, Val Accuracy: 71.01%
# Epoch 64/100, Loss: 0.0176, valid Loss: 1.357973190871152, Accuracy: 99.85%, Val Accuracy: 71.16%
# Epoch 65/100, Loss: 0.0350, valid Loss: 1.706619230183688, Accuracy: 99.05%, Val Accuracy: 74.52%
# Epoch 66/100, Loss: 0.0937, valid Loss: 1.1872720555825667, Accuracy: 97.00%, Val Accuracy: 70.72%
# Epoch 67/100, Loss: 0.0617, valid Loss: 1.1807133501226252, Accuracy: 98.17%, Val Accuracy: 71.74%
# Epoch 68/100, Loss: 0.0238, valid Loss: 1.3031543222340671, Accuracy: 99.52%, Val Accuracy: 71.45%
# Epoch 69/100, Loss: 0.0307, valid Loss: 1.2877149907025425, Accuracy: 99.27%, Val Accuracy: 73.65%
# Epoch 70/100, Loss: 0.0134, valid Loss: 1.3038658933206038, Accuracy: 99.82%, Val Accuracy: 71.30%
# Epoch 71/100, Loss: 0.0086, valid Loss: 1.3525760986588218, Accuracy: 99.85%, Val Accuracy: 70.72%
# Epoch 72/100, Loss: 0.0106, valid Loss: 1.5217473181811245, Accuracy: 99.78%, Val Accuracy: 73.21%
# Epoch 73/100, Loss: 0.0119, valid Loss: 1.3474986769936301, Accuracy: 99.82%, Val Accuracy: 72.62%
# Epoch 74/100, Loss: 0.0077, valid Loss: 1.410764916376634, Accuracy: 99.89%, Val Accuracy: 72.91%
# Epoch 75/100, Loss: 0.0060, valid Loss: 1.4162171428853816, Accuracy: 99.96%, Val Accuracy: 72.18%
# Epoch 76/100, Loss: 0.0037, valid Loss: 1.446174681186676, Accuracy: 100.00%, Val Accuracy: 72.62%
# Epoch 77/100, Loss: 0.0036, valid Loss: 1.4850605726242065, Accuracy: 99.96%, Val Accuracy: 72.33%
# Epoch 78/100, Loss: 0.0032, valid Loss: 1.505682040344585, Accuracy: 99.96%, Val Accuracy: 72.33%
# Epoch 79/100, Loss: 0.0026, valid Loss: 1.4934527277946472, Accuracy: 99.96%, Val Accuracy: 73.06%
# Epoch 80/100, Loss: 0.0031, valid Loss: 1.5133595737543972, Accuracy: 99.96%, Val Accuracy: 73.94%
# Epoch 81/100, Loss: 0.0060, valid Loss: 1.577133379199288, Accuracy: 99.85%, Val Accuracy: 70.13%
# Epoch 82/100, Loss: 0.0160, valid Loss: 1.6261101744391702, Accuracy: 99.60%, Val Accuracy: 73.65%
# Epoch 83/100, Loss: 0.0270, valid Loss: 1.4548034126108342, Accuracy: 99.34%, Val Accuracy: 71.16%
# Epoch 84/100, Loss: 0.0916, valid Loss: 1.3834197087721392, Accuracy: 97.14%, Val Accuracy: 72.18%
# Epoch 85/100, Loss: 0.0912, valid Loss: 1.3630239421671086, Accuracy: 96.74%, Val Accuracy: 69.99%
# Epoch 86/100, Loss: 0.0789, valid Loss: 1.0884708545424722, Accuracy: 97.44%, Val Accuracy: 71.89%
# Epoch 87/100, Loss: 0.0254, valid Loss: 1.279173645106229, Accuracy: 99.38%, Val Accuracy: 71.60%
# Epoch 88/100, Loss: 0.0092, valid Loss: 1.324039486321536, Accuracy: 99.89%, Val Accuracy: 70.72%
# Epoch 89/100, Loss: 0.0054, valid Loss: 1.4025440216064453, Accuracy: 99.93%, Val Accuracy: 73.06%
# Epoch 90/100, Loss: 0.0028, valid Loss: 1.4396637298844077, Accuracy: 100.00%, Val Accuracy: 73.50%
# Epoch 91/100, Loss: 0.0028, valid Loss: 1.446641125462272, Accuracy: 99.96%, Val Accuracy: 73.06%
# Epoch 92/100, Loss: 0.0025, valid Loss: 1.4629030281847173, Accuracy: 100.00%, Val Accuracy: 72.33%
# Epoch 93/100, Loss: 0.0022, valid Loss: 1.488004120913419, Accuracy: 100.00%, Val Accuracy: 72.18%
# Epoch 94/100, Loss: 0.0022, valid Loss: 1.5123293724927036, Accuracy: 100.00%, Val Accuracy: 72.33%
# Epoch 95/100, Loss: 0.0019, valid Loss: 1.5073256655172869, Accuracy: 100.00%, Val Accuracy: 71.30%
# Epoch 96/100, Loss: 0.0030, valid Loss: 1.5093551603230564, Accuracy: 99.93%, Val Accuracy: 71.01%
# Epoch 97/100, Loss: 0.0022, valid Loss: 1.5096939477053555, Accuracy: 99.96%, Val Accuracy: 71.60%
# Epoch 98/100, Loss: 0.0023, valid Loss: 1.5341007926247336, Accuracy: 100.00%, Val Accuracy: 72.04%
# Epoch 99/100, Loss: 0.0021, valid Loss: 1.530287580056624, Accuracy: 99.96%, Val Accuracy: 71.30%
# Epoch 100/100, Loss: 0.0029, valid Loss: 1.5399551066485317, Accuracy: 99.93%, Val Accuracy: 71.89%
# Best model reloaded with valid loss:  0.5836492451754484   time: 15

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
ax.set_ylim(0.0, 2.5)
ax2.set_ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_129659/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 69.321%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.699     0.856     0.770       472
#            1      0.510     0.273     0.356       194
#            2      1.000     0.289     0.449        38
#            3      0.770     0.827     0.797       150
#
#     accuracy                          0.693       854
#    macro avg      0.745     0.561     0.593       854
# weighted avg      0.682     0.693     0.666       854

# %%
val_mean = sum(validation_losses)/100
val_max = max(validation_losses)
val_min = min(validation_losses)

first = validation_losses[0]
end = validation_losses[99]
print("mean  ",val_mean)
print("max   ", val_max)
print("min   ", val_min)
print("first ", first)
print("end   ", end)
# Out:
# mean   1.063028437170115
# max    1.706619230183688
# min    0.5836492451754484
# first  0.7608422636985779
# end    1.5399551066485317
