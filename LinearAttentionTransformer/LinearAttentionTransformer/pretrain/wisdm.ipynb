# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../down_stream_dataset/wisdm_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (17916, 3, 300), Train label shape: (17916,)
# Valid data shape: (4480, 3, 300), Valid label shape: (4480,)
# Test data shape: (5600, 3, 300), Test label shape: (5600,)
# Scaled Train data shape: (17916, 3, 300)
# Scaled Valid data shape: (4480, 3, 300)
# Scaled Test data shape: (5600, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 16    1029
# 13    1025
# 17    1017
# 7     1013
# 11    1012
# 6     1008
# 15    1004
# 0     1001
# 12     996
# 1      994
# 8      990
# 5      988
# 10     987
# 2      980
# 3      971
# 9      970
# 14     967
# 4      964
# dtype: int64
# 14    352
# 3     337
# 2     332
# 15    326
# 9     322
# 1     320
# 5     318
# 6     310
# 8     308
# 10    308
# 4     307
# 7     306
# 17    305
# 0     300
# 13    296
# 12    291
# 11    286
# 16    276
# dtype: int64
# 4     271
# 9     265
# 12    263
# 10    259
# 16    255
# 11    254
# 8     253
# 1     250
# 14    249
# 2     248
# 5     247
# 6     245
# 0     245
# 7     245
# 3     240
# 15    233
# 13    232
# 17    226
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
state_dict = torch.load('path/pretrained_1/5_4pretrain_model_predict.pth')

# キー名の修正
new_state_dict = {}
for key, value in state_dict.items():
    new_key = key.replace("weights_", "weights.")  # キー名の変更
    new_state_dict[new_key] = value

# 修正済みの重みをモデルにロード
model.load_state_dict(new_state_dict, strict=True)
model.to(device)
# Out:
# 18
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 41
#      38     new_state_dict[new_key] = value
#      40 # 修正済みの重みをモデルにロード
# ---> 41 model.load_state_dict(new_state_dict, strict=True)
#      42 model.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LinearAttentionTransformerLM:
# 	Unexpected key(s) in state_dict: "predict.weight", "predict.bias".

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=768, out_features=768, bias=True)
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=18, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_wisdm_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_80220/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 1.9588, valid Loss: 1.7309756296021597, Accuracy: 33.32%, Val Accuracy: 40.94%
# Epoch 2/100, Loss: 1.5485, valid Loss: 1.5150555304118565, Accuracy: 45.74%, Val Accuracy: 47.39%
# Epoch 3/100, Loss: 1.3258, valid Loss: 1.2337297320365905, Accuracy: 52.89%, Val Accuracy: 55.89%
# Epoch 4/100, Loss: 1.1478, valid Loss: 1.1111652501991818, Accuracy: 59.74%, Val Accuracy: 60.33%
# Epoch 5/100, Loss: 1.0173, valid Loss: 1.0963616950171335, Accuracy: 63.98%, Val Accuracy: 61.07%
# Epoch 6/100, Loss: 0.9333, valid Loss: 1.046426077399935, Accuracy: 67.22%, Val Accuracy: 63.01%
# Epoch 7/100, Loss: 0.8397, valid Loss: 0.9719070485660009, Accuracy: 70.45%, Val Accuracy: 65.27%
# Epoch 8/100, Loss: 0.7640, valid Loss: 0.9981203726359776, Accuracy: 73.78%, Val Accuracy: 65.45%
# Epoch 9/100, Loss: 0.7012, valid Loss: 0.8502121508121491, Accuracy: 75.54%, Val Accuracy: 71.74%
# Epoch 10/100, Loss: 0.6563, valid Loss: 0.7854794502258301, Accuracy: 77.00%, Val Accuracy: 73.55%
# Epoch 11/100, Loss: 0.6202, valid Loss: 0.7669872556413923, Accuracy: 78.17%, Val Accuracy: 73.10%
# Epoch 12/100, Loss: 0.5694, valid Loss: 0.7352840261799949, Accuracy: 80.14%, Val Accuracy: 75.40%
# Epoch 13/100, Loss: 0.5393, valid Loss: 0.7154875823429653, Accuracy: 80.89%, Val Accuracy: 75.92%
# Epoch 14/100, Loss: 0.5128, valid Loss: 0.7532295567648751, Accuracy: 81.78%, Val Accuracy: 75.78%
# Epoch 15/100, Loss: 0.4809, valid Loss: 0.7254633809838976, Accuracy: 82.75%, Val Accuracy: 76.63%
# Epoch 16/100, Loss: 0.4550, valid Loss: 0.7597464974437441, Accuracy: 83.67%, Val Accuracy: 75.51%
# Epoch 17/100, Loss: 0.4375, valid Loss: 0.6792186941419329, Accuracy: 84.28%, Val Accuracy: 78.33%
# Epoch 18/100, Loss: 0.4165, valid Loss: 0.6884768392358508, Accuracy: 85.10%, Val Accuracy: 78.17%
# Epoch 19/100, Loss: 0.3907, valid Loss: 0.74037247470447, Accuracy: 86.05%, Val Accuracy: 77.01%
# Epoch 20/100, Loss: 0.3898, valid Loss: 0.7289607801607677, Accuracy: 85.91%, Val Accuracy: 76.79%
# Epoch 21/100, Loss: 0.3697, valid Loss: 0.7151793386254992, Accuracy: 86.73%, Val Accuracy: 77.59%
# Epoch 22/100, Loss: 0.3526, valid Loss: 0.7744146687643868, Accuracy: 87.22%, Val Accuracy: 77.08%
# Epoch 23/100, Loss: 0.3312, valid Loss: 0.751979713354792, Accuracy: 88.14%, Val Accuracy: 77.52%
# Epoch 24/100, Loss: 0.3024, valid Loss: 0.8185481016124998, Accuracy: 89.11%, Val Accuracy: 77.92%
# Epoch 25/100, Loss: 0.3092, valid Loss: 0.795623573235103, Accuracy: 88.95%, Val Accuracy: 78.15%
# Epoch 26/100, Loss: 0.2840, valid Loss: 0.8144094330923898, Accuracy: 89.81%, Val Accuracy: 78.04%
# Epoch 27/100, Loss: 0.2869, valid Loss: 0.8360317800726209, Accuracy: 89.45%, Val Accuracy: 77.61%
# Epoch 28/100, Loss: 0.2658, valid Loss: 0.8479878140347344, Accuracy: 90.39%, Val Accuracy: 77.25%
# Epoch 29/100, Loss: 0.2663, valid Loss: 0.7461783013173512, Accuracy: 90.20%, Val Accuracy: 78.77%
# Epoch 30/100, Loss: 0.2472, valid Loss: 0.8028449109622411, Accuracy: 91.03%, Val Accuracy: 77.92%
# Epoch 31/100, Loss: 0.2380, valid Loss: 0.8485789971692221, Accuracy: 91.27%, Val Accuracy: 78.91%
# Epoch 32/100, Loss: 0.2295, valid Loss: 0.7699794573443276, Accuracy: 91.63%, Val Accuracy: 80.20%
# Epoch 33/100, Loss: 0.2188, valid Loss: 0.8459257636751447, Accuracy: 92.09%, Val Accuracy: 79.22%
# Epoch 34/100, Loss: 0.2246, valid Loss: 0.7995337797062737, Accuracy: 91.85%, Val Accuracy: 80.09%
# Epoch 35/100, Loss: 0.2118, valid Loss: 0.8430207593100412, Accuracy: 92.33%, Val Accuracy: 79.67%
# Epoch 36/100, Loss: 0.2001, valid Loss: 0.8910318540675299, Accuracy: 92.50%, Val Accuracy: 78.53%
# Epoch 37/100, Loss: 0.1955, valid Loss: 0.8905557138579232, Accuracy: 92.87%, Val Accuracy: 79.08%
# Epoch 38/100, Loss: 0.1929, valid Loss: 0.8186321833303997, Accuracy: 93.07%, Val Accuracy: 80.76%
# Epoch 39/100, Loss: 0.1766, valid Loss: 0.9063025099890573, Accuracy: 93.69%, Val Accuracy: 78.86%
# Epoch 40/100, Loss: 0.1793, valid Loss: 0.8765910795756748, Accuracy: 93.55%, Val Accuracy: 79.46%
# Epoch 41/100, Loss: 0.1793, valid Loss: 0.8729172553334917, Accuracy: 93.46%, Val Accuracy: 79.00%
# Epoch 42/100, Loss: 0.1707, valid Loss: 0.9174740497555052, Accuracy: 93.88%, Val Accuracy: 78.26%
# Epoch 43/100, Loss: 0.1770, valid Loss: 0.938192994253976, Accuracy: 93.80%, Val Accuracy: 79.49%
# Epoch 44/100, Loss: 0.1650, valid Loss: 0.9065135938780648, Accuracy: 94.05%, Val Accuracy: 79.78%
# Epoch 45/100, Loss: 0.1488, valid Loss: 0.9786349534988403, Accuracy: 94.54%, Val Accuracy: 77.66%
# Epoch 46/100, Loss: 0.1634, valid Loss: 1.0027495196887426, Accuracy: 94.31%, Val Accuracy: 79.17%
# Epoch 47/100, Loss: 0.1527, valid Loss: 0.9478287215743746, Accuracy: 94.45%, Val Accuracy: 79.06%
# Epoch 48/100, Loss: 0.1365, valid Loss: 0.9450387230941227, Accuracy: 95.07%, Val Accuracy: 80.58%
# Epoch 49/100, Loss: 0.1293, valid Loss: 0.9278381415775844, Accuracy: 95.30%, Val Accuracy: 80.85%
# Epoch 50/100, Loss: 0.1280, valid Loss: 1.0320467829704285, Accuracy: 95.33%, Val Accuracy: 79.44%
# Epoch 51/100, Loss: 0.1430, valid Loss: 0.9325254414762769, Accuracy: 94.87%, Val Accuracy: 80.27%
# Epoch 52/100, Loss: 0.1354, valid Loss: 1.0623874136379787, Accuracy: 95.10%, Val Accuracy: 78.86%
# Epoch 53/100, Loss: 0.1486, valid Loss: 0.9665182305233819, Accuracy: 94.74%, Val Accuracy: 81.09%
# Epoch 54/100, Loss: 0.1073, valid Loss: 1.0190463947398323, Accuracy: 96.19%, Val Accuracy: 79.44%
# Epoch 55/100, Loss: 0.1312, valid Loss: 1.102893214566367, Accuracy: 95.16%, Val Accuracy: 77.68%
# Epoch 56/100, Loss: 0.1162, valid Loss: 1.0064678132534026, Accuracy: 95.80%, Val Accuracy: 80.22%
# Epoch 57/100, Loss: 0.1244, valid Loss: 0.9865722826548985, Accuracy: 95.64%, Val Accuracy: 80.04%
# Epoch 58/100, Loss: 0.1029, valid Loss: 1.0367146402597427, Accuracy: 96.33%, Val Accuracy: 78.68%
# Epoch 59/100, Loss: 0.1336, valid Loss: 0.9872463234833309, Accuracy: 95.22%, Val Accuracy: 81.52%
# Epoch 60/100, Loss: 0.1132, valid Loss: 1.0024485204901015, Accuracy: 95.95%, Val Accuracy: 80.29%
# Epoch 61/100, Loss: 0.1102, valid Loss: 1.074109570469175, Accuracy: 96.06%, Val Accuracy: 80.18%
# Epoch 62/100, Loss: 0.1173, valid Loss: 1.0173801179443087, Accuracy: 95.80%, Val Accuracy: 80.31%
# Epoch 63/100, Loss: 0.1130, valid Loss: 0.9929273000785283, Accuracy: 96.09%, Val Accuracy: 79.96%
# Epoch 64/100, Loss: 0.0956, valid Loss: 1.028195677484785, Accuracy: 96.61%, Val Accuracy: 80.09%
# Epoch 65/100, Loss: 0.1015, valid Loss: 1.1136282435485294, Accuracy: 96.39%, Val Accuracy: 78.82%
# Epoch 66/100, Loss: 0.1180, valid Loss: 1.1115382598979133, Accuracy: 95.89%, Val Accuracy: 78.82%
# Epoch 67/100, Loss: 0.1036, valid Loss: 1.0681863273893084, Accuracy: 96.33%, Val Accuracy: 79.87%
# Epoch 68/100, Loss: 0.0989, valid Loss: 1.0878733353955405, Accuracy: 96.47%, Val Accuracy: 80.00%
# Epoch 69/100, Loss: 0.1105, valid Loss: 1.0596538369144712, Accuracy: 96.11%, Val Accuracy: 80.31%
# Epoch 70/100, Loss: 0.0948, valid Loss: 1.0505994686058588, Accuracy: 96.60%, Val Accuracy: 80.47%
# Epoch 71/100, Loss: 0.0886, valid Loss: 1.0692432148115976, Accuracy: 96.68%, Val Accuracy: 80.27%
# Epoch 72/100, Loss: 0.1088, valid Loss: 1.095945929629462, Accuracy: 96.18%, Val Accuracy: 79.17%
# Epoch 73/100, Loss: 0.0798, valid Loss: 1.1029860147408077, Accuracy: 97.15%, Val Accuracy: 80.54%
# Epoch 74/100, Loss: 0.0784, valid Loss: 1.0700779923370907, Accuracy: 97.18%, Val Accuracy: 80.67%
# Epoch 75/100, Loss: 0.1095, valid Loss: 1.0949360911335264, Accuracy: 96.22%, Val Accuracy: 79.08%
# Epoch 76/100, Loss: 0.1092, valid Loss: 1.0438600208078113, Accuracy: 96.22%, Val Accuracy: 79.71%
# Epoch 77/100, Loss: 0.0800, valid Loss: 1.133608487674168, Accuracy: 97.14%, Val Accuracy: 79.42%
# Epoch 78/100, Loss: 0.0833, valid Loss: 1.0718161442450114, Accuracy: 97.12%, Val Accuracy: 78.28%
# Epoch 79/100, Loss: 0.0994, valid Loss: 1.167320767045021, Accuracy: 96.60%, Val Accuracy: 79.17%
# Epoch 80/100, Loss: 0.0861, valid Loss: 1.2522983048643386, Accuracy: 96.97%, Val Accuracy: 78.44%
# Epoch 81/100, Loss: 0.0794, valid Loss: 1.2140336666788374, Accuracy: 97.07%, Val Accuracy: 80.13%
# Epoch 82/100, Loss: 0.0801, valid Loss: 1.2055860561983927, Accuracy: 97.17%, Val Accuracy: 79.84%
# Epoch 83/100, Loss: 0.0829, valid Loss: 1.1214806011744909, Accuracy: 97.02%, Val Accuracy: 80.71%
# Epoch 84/100, Loss: 0.0676, valid Loss: 1.1537072948047093, Accuracy: 97.65%, Val Accuracy: 79.08%
# Epoch 85/100, Loss: 0.1077, valid Loss: 1.120512870805604, Accuracy: 96.12%, Val Accuracy: 78.82%
# Epoch 86/100, Loss: 0.0827, valid Loss: 1.1837210731846945, Accuracy: 97.00%, Val Accuracy: 78.73%
# Epoch 87/100, Loss: 0.0878, valid Loss: 1.0895730516740254, Accuracy: 97.05%, Val Accuracy: 79.58%
# Epoch 88/100, Loss: 0.0704, valid Loss: 1.2064402980463846, Accuracy: 97.44%, Val Accuracy: 80.00%
# Epoch 89/100, Loss: 0.0661, valid Loss: 1.1513467013835907, Accuracy: 97.67%, Val Accuracy: 80.89%
# Epoch 90/100, Loss: 0.0590, valid Loss: 1.218162567274911, Accuracy: 98.04%, Val Accuracy: 80.49%
# Epoch 91/100, Loss: 0.0773, valid Loss: 1.2604996302298137, Accuracy: 97.21%, Val Accuracy: 78.50%
# Epoch 92/100, Loss: 0.0923, valid Loss: 1.1603669668946948, Accuracy: 96.73%, Val Accuracy: 80.13%
# Epoch 93/100, Loss: 0.0896, valid Loss: 1.1132843221936908, Accuracy: 96.91%, Val Accuracy: 81.72%
# Epoch 94/100, Loss: 0.0596, valid Loss: 1.1664858962808335, Accuracy: 97.93%, Val Accuracy: 80.87%
# Epoch 95/100, Loss: 0.0523, valid Loss: 1.1886272809335163, Accuracy: 98.11%, Val Accuracy: 79.58%
# Epoch 96/100, Loss: 0.0794, valid Loss: 1.2077704795769282, Accuracy: 97.29%, Val Accuracy: 80.00%
# Epoch 97/100, Loss: 0.0753, valid Loss: 1.2591984455074583, Accuracy: 97.29%, Val Accuracy: 80.22%
# Epoch 98/100, Loss: 0.0672, valid Loss: 1.2000860448394504, Accuracy: 97.63%, Val Accuracy: 81.07%
# Epoch 99/100, Loss: 0.0639, valid Loss: 1.315081741980144, Accuracy: 97.75%, Val Accuracy: 78.62%
# Epoch 100/100, Loss: 0.0849, valid Loss: 1.2825308970042637, Accuracy: 97.10%, Val Accuracy: 78.73%
# Best model reloaded with valid loss:  0.6792186941419329   time: 17

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
ax.set_ylim(0.0, 2.5)
ax2.set_ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_80220/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 78.196%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.827     0.907     0.865       300
#            1      0.646     0.559     0.600       320
#            2      0.909     0.898     0.903       332
#            3      0.913     0.875     0.894       337
#            4      0.691     0.720     0.705       307
#            5      0.859     0.805     0.831       318
#            6      0.971     0.965     0.968       310
#            7      0.770     0.833     0.801       306
#            8      0.610     0.740     0.669       308
#            9      0.584     0.475     0.524       322
#           10      0.670     0.705     0.687       308
#           11      0.714     0.734     0.724       286
#           12      0.853     0.656     0.742       291
#           13      0.880     0.841     0.860       296
#           14      0.800     0.841     0.820       352
#           15      0.849     0.739     0.790       326
#           16      0.822     0.851     0.836       276
#           17      0.738     0.931     0.823       305
#
#     accuracy                          0.782      5600
#    macro avg      0.784     0.782     0.780      5600
# weighted avg      0.784     0.782     0.780      5600
