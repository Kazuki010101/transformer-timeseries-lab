# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../../down_stream_dataset/adl_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (406, 3, 300), Train label shape: (406,)
# Valid data shape: (102, 3, 300), Valid label shape: (102,)
# Test data shape: (127, 3, 300), Test label shape: (127,)
# Scaled Train data shape: (406, 3, 300)
# Scaled Valid data shape: (102, 3, 300)
# Scaled Test data shape: (127, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 4    186
# 1     62
# 2     58
# 3     54
# 0     46
# dtype: int64
# 4    51
# 1    25
# 3    22
# 2    19
# 0    10
# dtype: int64
# 4    42
# 1    18
# 3    17
# 2    15
# 0    10
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
model.to(device)
# Out:
# 5
# LinearAttentionTransformerLM(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
# )

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
# state_dict

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_adl_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_93921/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 1.8431, valid Loss: 1.0286739468574524, Accuracy: 37.44%, Val Accuracy: 60.78%
# Epoch 2/100, Loss: 0.8846, valid Loss: 0.6542167663574219, Accuracy: 65.52%, Val Accuracy: 78.43%
# Epoch 3/100, Loss: 0.6565, valid Loss: 0.6105712354183197, Accuracy: 77.34%, Val Accuracy: 77.45%
# Epoch 4/100, Loss: 0.5172, valid Loss: 0.5480763018131256, Accuracy: 81.28%, Val Accuracy: 81.37%
# Epoch 5/100, Loss: 0.5036, valid Loss: 0.5453413724899292, Accuracy: 82.27%, Val Accuracy: 82.35%
# Epoch 6/100, Loss: 0.4493, valid Loss: 0.7378135323524475, Accuracy: 83.00%, Val Accuracy: 72.55%
# Epoch 7/100, Loss: 0.4682, valid Loss: 0.48677319288253784, Accuracy: 81.28%, Val Accuracy: 82.35%
# Epoch 8/100, Loss: 0.4758, valid Loss: 0.49407269060611725, Accuracy: 81.53%, Val Accuracy: 80.39%
# Epoch 9/100, Loss: 0.3926, valid Loss: 0.6248285472393036, Accuracy: 85.22%, Val Accuracy: 74.51%
# Epoch 10/100, Loss: 0.4160, valid Loss: 0.45962847769260406, Accuracy: 82.76%, Val Accuracy: 81.37%
# Epoch 11/100, Loss: 0.3406, valid Loss: 0.5050146877765656, Accuracy: 88.67%, Val Accuracy: 82.35%
# Epoch 12/100, Loss: 0.2991, valid Loss: 0.4460851848125458, Accuracy: 89.16%, Val Accuracy: 84.31%
# Epoch 13/100, Loss: 0.3622, valid Loss: 0.5209063440561295, Accuracy: 84.73%, Val Accuracy: 82.35%
# Epoch 14/100, Loss: 0.2911, valid Loss: 0.4044005572795868, Accuracy: 88.18%, Val Accuracy: 85.29%
# Epoch 15/100, Loss: 0.2699, valid Loss: 0.7178614288568497, Accuracy: 90.15%, Val Accuracy: 77.45%
# Epoch 16/100, Loss: 0.3967, valid Loss: 0.6319346874952316, Accuracy: 84.73%, Val Accuracy: 84.31%
# Epoch 17/100, Loss: 0.3990, valid Loss: 0.6096509099006653, Accuracy: 83.74%, Val Accuracy: 77.45%
# Epoch 18/100, Loss: 0.3127, valid Loss: 0.5052967220544815, Accuracy: 89.16%, Val Accuracy: 81.37%
# Epoch 19/100, Loss: 0.2725, valid Loss: 0.4581334739923477, Accuracy: 88.67%, Val Accuracy: 83.33%
# Epoch 20/100, Loss: 0.2809, valid Loss: 0.5070537030696869, Accuracy: 89.90%, Val Accuracy: 79.41%
# Epoch 21/100, Loss: 0.2723, valid Loss: 0.4578411281108856, Accuracy: 90.39%, Val Accuracy: 83.33%
# Epoch 22/100, Loss: 0.2909, valid Loss: 0.439924418926239, Accuracy: 89.66%, Val Accuracy: 83.33%
# Epoch 23/100, Loss: 0.2590, valid Loss: 0.5231842547655106, Accuracy: 90.15%, Val Accuracy: 82.35%
# Epoch 24/100, Loss: 0.2435, valid Loss: 0.40190379321575165, Accuracy: 90.89%, Val Accuracy: 84.31%
# Epoch 25/100, Loss: 0.2319, valid Loss: 0.4681266248226166, Accuracy: 91.38%, Val Accuracy: 84.31%
# Epoch 26/100, Loss: 0.2368, valid Loss: 0.5088957697153091, Accuracy: 92.61%, Val Accuracy: 83.33%
# Epoch 27/100, Loss: 0.2341, valid Loss: 0.4184805601835251, Accuracy: 92.36%, Val Accuracy: 82.35%
# Epoch 28/100, Loss: 0.2075, valid Loss: 0.4301762729883194, Accuracy: 93.35%, Val Accuracy: 87.25%
# Epoch 29/100, Loss: 0.1943, valid Loss: 0.3936165124177933, Accuracy: 93.35%, Val Accuracy: 86.27%
# Epoch 30/100, Loss: 0.2080, valid Loss: 0.74208864569664, Accuracy: 93.84%, Val Accuracy: 64.71%
# Epoch 31/100, Loss: 0.2835, valid Loss: 0.5475704371929169, Accuracy: 88.18%, Val Accuracy: 78.43%
# Epoch 32/100, Loss: 0.2260, valid Loss: 0.42525482177734375, Accuracy: 90.64%, Val Accuracy: 83.33%
# Epoch 33/100, Loss: 0.1985, valid Loss: 0.4097709357738495, Accuracy: 92.86%, Val Accuracy: 86.27%
# Epoch 34/100, Loss: 0.1687, valid Loss: 0.3974895179271698, Accuracy: 94.09%, Val Accuracy: 89.22%
# Epoch 35/100, Loss: 0.1457, valid Loss: 0.47478291392326355, Accuracy: 95.32%, Val Accuracy: 89.22%
# Epoch 36/100, Loss: 0.1530, valid Loss: 0.41925571858882904, Accuracy: 94.09%, Val Accuracy: 88.24%
# Epoch 37/100, Loss: 0.1341, valid Loss: 0.38827162981033325, Accuracy: 95.32%, Val Accuracy: 88.24%
# Epoch 38/100, Loss: 0.1808, valid Loss: 0.7162514626979828, Accuracy: 94.83%, Val Accuracy: 70.59%
# Epoch 39/100, Loss: 0.2288, valid Loss: 0.4562207758426666, Accuracy: 90.89%, Val Accuracy: 82.35%
# Epoch 40/100, Loss: 0.2524, valid Loss: 0.49375247955322266, Accuracy: 89.41%, Val Accuracy: 79.41%
# Epoch 41/100, Loss: 0.2304, valid Loss: 0.6082141995429993, Accuracy: 91.38%, Val Accuracy: 82.35%
# Epoch 42/100, Loss: 0.2365, valid Loss: 0.6534295082092285, Accuracy: 91.63%, Val Accuracy: 78.43%
# Epoch 43/100, Loss: 0.2116, valid Loss: 0.383827805519104, Accuracy: 91.87%, Val Accuracy: 85.29%
# Epoch 44/100, Loss: 0.2005, valid Loss: 0.35056231915950775, Accuracy: 92.36%, Val Accuracy: 89.22%
# Epoch 45/100, Loss: 0.1976, valid Loss: 0.5489658117294312, Accuracy: 93.84%, Val Accuracy: 86.27%
# Epoch 46/100, Loss: 0.2576, valid Loss: 0.5895029008388519, Accuracy: 90.89%, Val Accuracy: 82.35%
# Epoch 47/100, Loss: 0.3170, valid Loss: 0.5927352458238602, Accuracy: 88.92%, Val Accuracy: 80.39%
# Epoch 48/100, Loss: 0.2480, valid Loss: 0.49590013921260834, Accuracy: 92.12%, Val Accuracy: 83.33%
# Epoch 49/100, Loss: 0.1892, valid Loss: 0.42781367897987366, Accuracy: 92.61%, Val Accuracy: 88.24%
# Epoch 50/100, Loss: 0.1251, valid Loss: 0.4914895296096802, Accuracy: 95.32%, Val Accuracy: 83.33%
# Epoch 51/100, Loss: 0.1101, valid Loss: 0.5014861673116684, Accuracy: 95.81%, Val Accuracy: 84.31%
# Epoch 52/100, Loss: 0.0924, valid Loss: 0.482941210269928, Accuracy: 96.55%, Val Accuracy: 83.33%
# Epoch 53/100, Loss: 0.2106, valid Loss: 0.5108450204133987, Accuracy: 92.86%, Val Accuracy: 82.35%
# Epoch 54/100, Loss: 0.2198, valid Loss: 0.6509290933609009, Accuracy: 87.68%, Val Accuracy: 81.37%
# Epoch 55/100, Loss: 0.2616, valid Loss: 0.46338988840579987, Accuracy: 90.15%, Val Accuracy: 86.27%
# Epoch 56/100, Loss: 0.2070, valid Loss: 0.49415434896945953, Accuracy: 92.12%, Val Accuracy: 84.31%
# Epoch 57/100, Loss: 0.1535, valid Loss: 0.5122343599796295, Accuracy: 93.84%, Val Accuracy: 83.33%
# Epoch 58/100, Loss: 0.1294, valid Loss: 0.4452087730169296, Accuracy: 94.83%, Val Accuracy: 86.27%
# Epoch 59/100, Loss: 0.1016, valid Loss: 0.487973690032959, Accuracy: 96.55%, Val Accuracy: 86.27%
# Epoch 60/100, Loss: 0.0872, valid Loss: 0.5133289843797684, Accuracy: 96.55%, Val Accuracy: 86.27%
# Epoch 61/100, Loss: 0.1098, valid Loss: 0.6456982791423798, Accuracy: 96.06%, Val Accuracy: 78.43%
# Epoch 62/100, Loss: 0.0882, valid Loss: 0.5766125321388245, Accuracy: 97.04%, Val Accuracy: 83.33%
# Epoch 63/100, Loss: 0.1334, valid Loss: 0.503266230225563, Accuracy: 95.81%, Val Accuracy: 84.31%
# Epoch 64/100, Loss: 0.1637, valid Loss: 0.5738496035337448, Accuracy: 94.09%, Val Accuracy: 80.39%
# Epoch 65/100, Loss: 0.1139, valid Loss: 0.5047484785318375, Accuracy: 95.81%, Val Accuracy: 85.29%
# Epoch 66/100, Loss: 0.0938, valid Loss: 0.4450746327638626, Accuracy: 96.55%, Val Accuracy: 88.24%
# Epoch 67/100, Loss: 0.1186, valid Loss: 0.5065662413835526, Accuracy: 96.31%, Val Accuracy: 83.33%
# Epoch 68/100, Loss: 0.0980, valid Loss: 0.5272694677114487, Accuracy: 97.78%, Val Accuracy: 85.29%
# Epoch 69/100, Loss: 0.0957, valid Loss: 0.5406982898712158, Accuracy: 96.31%, Val Accuracy: 83.33%
# Epoch 70/100, Loss: 0.0531, valid Loss: 0.45506201684474945, Accuracy: 98.52%, Val Accuracy: 85.29%
# Epoch 71/100, Loss: 0.0475, valid Loss: 0.4442281723022461, Accuracy: 99.01%, Val Accuracy: 89.22%
# Epoch 72/100, Loss: 0.0484, valid Loss: 0.4841734617948532, Accuracy: 98.52%, Val Accuracy: 86.27%
# Epoch 73/100, Loss: 0.0405, valid Loss: 0.49428026378154755, Accuracy: 99.01%, Val Accuracy: 89.22%
# Epoch 74/100, Loss: 0.0257, valid Loss: 0.5160472840070724, Accuracy: 99.26%, Val Accuracy: 87.25%
# Epoch 75/100, Loss: 0.0229, valid Loss: 0.5135404020547867, Accuracy: 99.01%, Val Accuracy: 90.20%
# Epoch 76/100, Loss: 0.0328, valid Loss: 0.5052960216999054, Accuracy: 99.01%, Val Accuracy: 86.27%
# Epoch 77/100, Loss: 0.1306, valid Loss: 0.5852337628602982, Accuracy: 95.57%, Val Accuracy: 86.27%
# Epoch 78/100, Loss: 0.2305, valid Loss: 0.9781844019889832, Accuracy: 96.80%, Val Accuracy: 74.51%
# Epoch 79/100, Loss: 0.3661, valid Loss: 0.673550546169281, Accuracy: 89.41%, Val Accuracy: 74.51%
# Epoch 80/100, Loss: 0.2689, valid Loss: 0.6317851841449738, Accuracy: 90.64%, Val Accuracy: 78.43%
# Epoch 81/100, Loss: 0.1890, valid Loss: 0.6310631930828094, Accuracy: 93.60%, Val Accuracy: 81.37%
# Epoch 82/100, Loss: 0.1443, valid Loss: 0.4700934737920761, Accuracy: 95.07%, Val Accuracy: 88.24%
# Epoch 83/100, Loss: 0.1027, valid Loss: 0.5264154225587845, Accuracy: 95.81%, Val Accuracy: 82.35%
# Epoch 84/100, Loss: 0.0872, valid Loss: 0.5999256372451782, Accuracy: 97.04%, Val Accuracy: 83.33%
# Epoch 85/100, Loss: 0.0722, valid Loss: 0.6423323452472687, Accuracy: 96.80%, Val Accuracy: 84.31%
# Epoch 86/100, Loss: 0.0674, valid Loss: 0.6007882356643677, Accuracy: 97.78%, Val Accuracy: 82.35%
# Epoch 87/100, Loss: 0.0529, valid Loss: 0.6271689236164093, Accuracy: 98.52%, Val Accuracy: 81.37%
# Epoch 88/100, Loss: 0.0725, valid Loss: 0.5365754812955856, Accuracy: 97.04%, Val Accuracy: 89.22%
# Epoch 89/100, Loss: 0.0618, valid Loss: 0.5831195116043091, Accuracy: 97.78%, Val Accuracy: 82.35%
# Epoch 90/100, Loss: 0.0480, valid Loss: 0.5418935120105743, Accuracy: 98.52%, Val Accuracy: 87.25%
# Epoch 91/100, Loss: 0.0404, valid Loss: 0.6042946577072144, Accuracy: 98.52%, Val Accuracy: 83.33%
# Epoch 92/100, Loss: 0.0333, valid Loss: 0.6182580888271332, Accuracy: 98.28%, Val Accuracy: 85.29%
# Epoch 93/100, Loss: 0.0248, valid Loss: 0.7188113629817963, Accuracy: 99.26%, Val Accuracy: 84.31%
# Epoch 94/100, Loss: 0.1154, valid Loss: 0.5913807153701782, Accuracy: 97.04%, Val Accuracy: 87.25%
# Epoch 95/100, Loss: 0.0833, valid Loss: 0.7950010299682617, Accuracy: 97.54%, Val Accuracy: 82.35%
# Epoch 96/100, Loss: 0.0695, valid Loss: 0.6905736923217773, Accuracy: 96.80%, Val Accuracy: 86.27%
# Epoch 97/100, Loss: 0.1748, valid Loss: 0.8644780218601227, Accuracy: 95.57%, Val Accuracy: 81.37%
# Epoch 98/100, Loss: 0.3549, valid Loss: 1.0175020098686218, Accuracy: 91.38%, Val Accuracy: 73.53%
# Epoch 99/100, Loss: 0.3563, valid Loss: 0.7706311047077179, Accuracy: 87.19%, Val Accuracy: 81.37%
# Epoch 100/100, Loss: 0.1931, valid Loss: 0.707973062992096, Accuracy: 93.35%, Val Accuracy: 82.35%
# Best model reloaded with valid loss:  0.35056231915950775   time: 44

# %%
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# Best model reloaded with valid loss:  0.35056231915950775   time: 44

# %%
# val_loss = []
# for i in range(num_epochs):
#     value = validation_losses[i].item()
#     val_loss.append(value)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
plt.ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = train_model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_93921/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 87.402%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.429     0.600     0.500        10
#            1      0.926     1.000     0.962        25
#            2      0.889     0.842     0.865        19
#            3      1.000     0.909     0.952        22
#            4      0.917     0.863     0.889        51
#
#     accuracy                          0.874       127
#    macro avg      0.832     0.843     0.834       127
# weighted avg      0.890     0.874     0.880       127

# %%
val_mean = sum(validation_losses)/100
val_max = max(validation_losses)
val_min = min(validation_losses)

first = validation_losses[0]
end = validation_losses[99]
print("mean  ",val_mean)
print("max   ", val_max)
print("min   ", val_min)
print("first ", first)
print("end   ", end)
# Out:
# mean   0.5545756986737251
# max    1.0286739468574524
# min    0.35056231915950775
# first  1.0286739468574524
# end    0.707973062992096
