# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../../down_stream_dataset/realworld_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (7964, 3, 300), Train label shape: (7964,)
# Valid data shape: (1992, 3, 300), Valid label shape: (1992,)
# Test data shape: (2490, 3, 300), Test label shape: (2490,)
# Scaled Train data shape: (7964, 3, 300)
# Scaled Valid data shape: (1992, 3, 300)
# Scaled Test data shape: (2490, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 4    1297
# 3    1139
# 5    1126
# 1    1119
# 6    1115
# 7    1102
# 0     900
# 2     166
# dtype: int64
# 4    390
# 7    379
# 3    357
# 6    351
# 1    351
# 5    348
# 0    268
# 2     46
# dtype: int64
# 4    315
# 7    308
# 5    299
# 6    283
# 3    278
# 1    261
# 0    208
# 2     40
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
model.to(device)
# Out:
# 8
# LinearAttentionTransformerLM(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=768, out_features=768, bias=True)
# )

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=768, out_features=768, bias=True)
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=8, bias=True)
# )

# %%
# state_dict

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_realworld_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_90689/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 1.3505, valid Loss: 1.2436464950442314, Accuracy: 45.17%, Val Accuracy: 53.56%
# Epoch 2/100, Loss: 1.1484, valid Loss: 1.1379886753857136, Accuracy: 53.00%, Val Accuracy: 53.97%
# Epoch 3/100, Loss: 1.0358, valid Loss: 1.0014526136219501, Accuracy: 58.17%, Val Accuracy: 59.04%
# Epoch 4/100, Loss: 0.9108, valid Loss: 1.2059540245682001, Accuracy: 64.14%, Val Accuracy: 56.98%
# Epoch 5/100, Loss: 0.8493, valid Loss: 0.8458761628717184, Accuracy: 66.64%, Val Accuracy: 66.52%
# Epoch 6/100, Loss: 0.7412, valid Loss: 0.7401613481342793, Accuracy: 71.26%, Val Accuracy: 70.68%
# Epoch 7/100, Loss: 0.6851, valid Loss: 0.6855653775855899, Accuracy: 73.24%, Val Accuracy: 72.84%
# Epoch 8/100, Loss: 0.6331, valid Loss: 0.6736795185133815, Accuracy: 76.18%, Val Accuracy: 76.26%
# Epoch 9/100, Loss: 0.6148, valid Loss: 0.683404128998518, Accuracy: 76.56%, Val Accuracy: 77.91%
# Epoch 10/100, Loss: 0.5771, valid Loss: 0.6781546818092465, Accuracy: 78.29%, Val Accuracy: 75.85%
# Epoch 11/100, Loss: 0.5420, valid Loss: 0.6329826060682535, Accuracy: 79.88%, Val Accuracy: 78.36%
# Epoch 12/100, Loss: 0.5470, valid Loss: 0.6353465495631099, Accuracy: 79.73%, Val Accuracy: 77.31%
# Epoch 13/100, Loss: 0.4967, valid Loss: 0.7203761674463749, Accuracy: 82.30%, Val Accuracy: 73.24%
# Epoch 14/100, Loss: 0.4751, valid Loss: 0.6050512995570898, Accuracy: 82.81%, Val Accuracy: 79.57%
# Epoch 15/100, Loss: 0.4433, valid Loss: 0.5630885949358344, Accuracy: 83.97%, Val Accuracy: 82.43%
# Epoch 16/100, Loss: 0.4287, valid Loss: 0.5472372211515903, Accuracy: 84.86%, Val Accuracy: 80.52%
# Epoch 17/100, Loss: 0.4111, valid Loss: 0.53591976640746, Accuracy: 85.11%, Val Accuracy: 81.83%
# Epoch 18/100, Loss: 0.3936, valid Loss: 0.5411960110068321, Accuracy: 86.13%, Val Accuracy: 82.08%
# Epoch 19/100, Loss: 0.3971, valid Loss: 0.6104673836380243, Accuracy: 85.57%, Val Accuracy: 80.72%
# Epoch 20/100, Loss: 0.3734, valid Loss: 0.5222155628725886, Accuracy: 87.08%, Val Accuracy: 82.48%
# Epoch 21/100, Loss: 0.3669, valid Loss: 0.5260766251012683, Accuracy: 87.10%, Val Accuracy: 83.94%
# Epoch 22/100, Loss: 0.3361, valid Loss: 0.55851138709113, Accuracy: 88.27%, Val Accuracy: 82.23%
# Epoch 23/100, Loss: 0.3146, valid Loss: 0.5696550216525793, Accuracy: 88.85%, Val Accuracy: 82.23%
# Epoch 24/100, Loss: 0.3058, valid Loss: 0.5578638250008225, Accuracy: 89.21%, Val Accuracy: 83.03%
# Epoch 25/100, Loss: 0.3304, valid Loss: 0.6313697472214699, Accuracy: 88.36%, Val Accuracy: 81.12%
# Epoch 26/100, Loss: 0.3084, valid Loss: 0.6366080474108458, Accuracy: 89.25%, Val Accuracy: 80.37%
# Epoch 27/100, Loss: 0.3020, valid Loss: 0.5827471101656556, Accuracy: 89.41%, Val Accuracy: 80.97%
# Epoch 28/100, Loss: 0.2849, valid Loss: 0.5310699678957462, Accuracy: 89.94%, Val Accuracy: 82.33%
# Epoch 29/100, Loss: 0.2947, valid Loss: 0.5127866822294891, Accuracy: 89.74%, Val Accuracy: 83.79%
# Epoch 30/100, Loss: 0.2556, valid Loss: 0.5815801993012428, Accuracy: 91.05%, Val Accuracy: 82.83%
# Epoch 31/100, Loss: 0.2544, valid Loss: 0.644625904969871, Accuracy: 90.87%, Val Accuracy: 81.17%
# Epoch 32/100, Loss: 0.2508, valid Loss: 0.6724288873374462, Accuracy: 90.77%, Val Accuracy: 81.53%
# Epoch 33/100, Loss: 0.2691, valid Loss: 0.6072691096924245, Accuracy: 90.48%, Val Accuracy: 82.18%
# Epoch 34/100, Loss: 0.2659, valid Loss: 0.6112708877772093, Accuracy: 90.16%, Val Accuracy: 82.83%
# Epoch 35/100, Loss: 0.2448, valid Loss: 0.5897287740372121, Accuracy: 91.06%, Val Accuracy: 83.58%
# Epoch 36/100, Loss: 0.2659, valid Loss: 0.6388828875496984, Accuracy: 90.41%, Val Accuracy: 80.52%
# Epoch 37/100, Loss: 0.2251, valid Loss: 0.5752479070797563, Accuracy: 91.78%, Val Accuracy: 83.89%
# Epoch 38/100, Loss: 0.2432, valid Loss: 0.6326914452947676, Accuracy: 91.20%, Val Accuracy: 82.58%
# Epoch 39/100, Loss: 0.2393, valid Loss: 0.6304336078464985, Accuracy: 91.40%, Val Accuracy: 81.93%
# Epoch 40/100, Loss: 0.2187, valid Loss: 0.6857632473111153, Accuracy: 91.79%, Val Accuracy: 82.78%
# Epoch 41/100, Loss: 0.2112, valid Loss: 0.6089253197424114, Accuracy: 92.40%, Val Accuracy: 82.63%
# Epoch 42/100, Loss: 0.1951, valid Loss: 0.6897301217541099, Accuracy: 92.77%, Val Accuracy: 81.98%
# Epoch 43/100, Loss: 0.2115, valid Loss: 0.6926031177863479, Accuracy: 92.01%, Val Accuracy: 82.43%
# Epoch 44/100, Loss: 0.2061, valid Loss: 0.6429287330247462, Accuracy: 92.44%, Val Accuracy: 83.99%
# Epoch 45/100, Loss: 0.1837, valid Loss: 0.6915138922631741, Accuracy: 93.27%, Val Accuracy: 81.78%
# Epoch 46/100, Loss: 0.1983, valid Loss: 0.7181855067610741, Accuracy: 92.75%, Val Accuracy: 82.23%
# Epoch 47/100, Loss: 0.1941, valid Loss: 0.6506861774250865, Accuracy: 92.52%, Val Accuracy: 83.63%
# Epoch 48/100, Loss: 0.1764, valid Loss: 0.6508559281937778, Accuracy: 93.58%, Val Accuracy: 83.43%
# Epoch 49/100, Loss: 0.1936, valid Loss: 0.6824126960709691, Accuracy: 92.82%, Val Accuracy: 83.38%
# Epoch 50/100, Loss: 0.1886, valid Loss: 0.6958911563269794, Accuracy: 93.13%, Val Accuracy: 82.28%
# Epoch 51/100, Loss: 0.1698, valid Loss: 0.6605225396342576, Accuracy: 93.73%, Val Accuracy: 83.89%
# Epoch 52/100, Loss: 0.1607, valid Loss: 0.6839463012292981, Accuracy: 94.24%, Val Accuracy: 83.38%
# Epoch 53/100, Loss: 0.1687, valid Loss: 0.6952513875439763, Accuracy: 93.82%, Val Accuracy: 82.73%
# Epoch 54/100, Loss: 0.1548, valid Loss: 0.7059051878750324, Accuracy: 94.24%, Val Accuracy: 83.43%
# Epoch 55/100, Loss: 0.1720, valid Loss: 0.813294735737145, Accuracy: 93.60%, Val Accuracy: 82.33%
# Epoch 56/100, Loss: 0.2030, valid Loss: 0.6561577962711453, Accuracy: 92.74%, Val Accuracy: 83.13%
# Epoch 57/100, Loss: 0.1495, valid Loss: 0.7673882523085922, Accuracy: 94.45%, Val Accuracy: 83.58%
# Epoch 58/100, Loss: 0.1657, valid Loss: 0.6647166153416038, Accuracy: 94.09%, Val Accuracy: 83.84%
# Epoch 59/100, Loss: 0.1554, valid Loss: 0.7637973786331713, Accuracy: 94.19%, Val Accuracy: 83.89%
# Epoch 60/100, Loss: 0.1413, valid Loss: 0.7371603604406118, Accuracy: 94.78%, Val Accuracy: 83.79%
# Epoch 61/100, Loss: 0.1543, valid Loss: 0.717749260365963, Accuracy: 94.06%, Val Accuracy: 84.29%
# Epoch 62/100, Loss: 0.1444, valid Loss: 0.831156313419342, Accuracy: 94.78%, Val Accuracy: 82.68%
# Epoch 63/100, Loss: 0.1553, valid Loss: 0.7064674627035856, Accuracy: 94.16%, Val Accuracy: 82.83%
# Epoch 64/100, Loss: 0.1507, valid Loss: 0.7789955218322575, Accuracy: 94.46%, Val Accuracy: 82.88%
# Epoch 65/100, Loss: 0.1635, valid Loss: 0.7030222811736166, Accuracy: 93.68%, Val Accuracy: 83.89%
# Epoch 66/100, Loss: 0.1303, valid Loss: 0.6986544616520405, Accuracy: 95.04%, Val Accuracy: 83.58%
# Epoch 67/100, Loss: 0.1523, valid Loss: 0.6994749181903899, Accuracy: 94.25%, Val Accuracy: 84.79%
# Epoch 68/100, Loss: 0.1469, valid Loss: 0.7164477221667767, Accuracy: 94.42%, Val Accuracy: 84.29%
# Epoch 69/100, Loss: 0.1092, valid Loss: 0.7879682257771492, Accuracy: 95.87%, Val Accuracy: 84.34%
# Epoch 70/100, Loss: 0.1267, valid Loss: 0.764039765112102, Accuracy: 95.23%, Val Accuracy: 83.53%
# Epoch 71/100, Loss: 0.1218, valid Loss: 0.8282440006732941, Accuracy: 95.29%, Val Accuracy: 83.48%
# Epoch 72/100, Loss: 0.1304, valid Loss: 0.8616177635267377, Accuracy: 94.89%, Val Accuracy: 82.43%
# Epoch 73/100, Loss: 0.1281, valid Loss: 0.8192120837047696, Accuracy: 95.20%, Val Accuracy: 82.48%
# Epoch 74/100, Loss: 0.1679, valid Loss: 0.8473318424075842, Accuracy: 93.94%, Val Accuracy: 82.58%
# Epoch 75/100, Loss: 0.1497, valid Loss: 0.7367518993560225, Accuracy: 94.41%, Val Accuracy: 84.64%
# Epoch 76/100, Loss: 0.1247, valid Loss: 0.7690699144732207, Accuracy: 95.23%, Val Accuracy: 84.04%
# Epoch 77/100, Loss: 0.1238, valid Loss: 0.8269431623630226, Accuracy: 94.98%, Val Accuracy: 81.68%
# Epoch 78/100, Loss: 0.1371, valid Loss: 0.8188479468226433, Accuracy: 94.78%, Val Accuracy: 83.03%
# Epoch 79/100, Loss: 0.1230, valid Loss: 0.8034347980283201, Accuracy: 95.20%, Val Accuracy: 83.23%
# Epoch 80/100, Loss: 0.1320, valid Loss: 0.7691793441772461, Accuracy: 95.14%, Val Accuracy: 84.39%
# Epoch 81/100, Loss: 0.1060, valid Loss: 0.7579698110930622, Accuracy: 95.91%, Val Accuracy: 85.24%
# Epoch 82/100, Loss: 0.1016, valid Loss: 0.7855071612866595, Accuracy: 95.97%, Val Accuracy: 83.48%
# Epoch 83/100, Loss: 0.1448, valid Loss: 0.6901119682006538, Accuracy: 94.60%, Val Accuracy: 84.09%
# Epoch 84/100, Loss: 0.1149, valid Loss: 0.8042809269391, Accuracy: 95.79%, Val Accuracy: 83.03%
# Epoch 85/100, Loss: 0.1171, valid Loss: 0.759948767721653, Accuracy: 95.38%, Val Accuracy: 83.84%
# Epoch 86/100, Loss: 0.0962, valid Loss: 0.8036001527216285, Accuracy: 96.06%, Val Accuracy: 83.99%
# Epoch 87/100, Loss: 0.1206, valid Loss: 0.7719282400794327, Accuracy: 95.44%, Val Accuracy: 84.29%
# Epoch 88/100, Loss: 0.1165, valid Loss: 0.8174667721614242, Accuracy: 95.52%, Val Accuracy: 81.83%
# Epoch 89/100, Loss: 0.1483, valid Loss: 0.7639621775597334, Accuracy: 94.42%, Val Accuracy: 82.48%
# Epoch 90/100, Loss: 0.1216, valid Loss: 0.7965105148032308, Accuracy: 95.30%, Val Accuracy: 82.48%
# Epoch 91/100, Loss: 0.1056, valid Loss: 0.7749710795469582, Accuracy: 95.91%, Val Accuracy: 84.84%
# Epoch 92/100, Loss: 0.1134, valid Loss: 0.7465037908405066, Accuracy: 95.61%, Val Accuracy: 83.28%
# Epoch 93/100, Loss: 0.1186, valid Loss: 0.8443276146426797, Accuracy: 95.73%, Val Accuracy: 82.48%
# Epoch 94/100, Loss: 0.1094, valid Loss: 0.7591402616817504, Accuracy: 95.71%, Val Accuracy: 84.39%
# Epoch 95/100, Loss: 0.1006, valid Loss: 0.7365909526124597, Accuracy: 95.96%, Val Accuracy: 84.89%
# Epoch 96/100, Loss: 0.1130, valid Loss: 0.7734494130127132, Accuracy: 95.68%, Val Accuracy: 84.04%
# Epoch 97/100, Loss: 0.1024, valid Loss: 0.8319997475482523, Accuracy: 95.93%, Val Accuracy: 84.74%
# Epoch 98/100, Loss: 0.0844, valid Loss: 0.810766767244786, Accuracy: 96.53%, Val Accuracy: 84.14%
# Epoch 99/100, Loss: 0.0975, valid Loss: 0.814862422645092, Accuracy: 95.92%, Val Accuracy: 83.43%
# Epoch 100/100, Loss: 0.1440, valid Loss: 0.7821912048384547, Accuracy: 94.64%, Val Accuracy: 81.93%
# Best model reloaded with valid loss:  0.5127866822294891   time: 29

# %%
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# Best model reloaded with valid loss:  0.5127866822294891   time: 29

# %%
# val_loss = []
# for i in range(num_epochs):
#     value = validation_losses[i].item()
#     val_loss.append(value)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
ax.set_ylim(0.0, 2.5)
ax2.set_ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = train_model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_90689/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 82.048%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.805     0.724     0.762       268
#            1      0.735     0.752     0.744       351
#            2      1.000     0.935     0.966        46
#            3      0.892     0.880     0.886       357
#            4      0.960     0.854     0.904       390
#            5      0.749     0.868     0.804       348
#            6      0.766     0.829     0.796       351
#            7      0.827     0.797     0.812       379
#
#     accuracy                          0.820      2490
#    macro avg      0.842     0.830     0.834      2490
# weighted avg      0.826     0.820     0.821      2490
