# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../down_stream_dataset/pamap_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (1836, 3, 300), Train label shape: (1836,)
# Valid data shape: (459, 3, 300), Valid label shape: (459,)
# Test data shape: (574, 3, 300), Test label shape: (574,)
# Scaled Train data shape: (1836, 3, 300)
# Scaled Valid data shape: (459, 3, 300)
# Scaled Test data shape: (574, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 7    309
# 3    308
# 0    241
# 2    238
# 6    234
# 1    228
# 4    159
# 5    119
# dtype: int64
# 0    88
# 7    83
# 1    82
# 3    79
# 2    69
# 6    66
# 4    55
# 5    52
# dtype: int64
# 7    85
# 3    76
# 2    72
# 1    58
# 0    56
# 6    50
# 5    39
# 4    23
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
state_dict = torch.load('path/pretrained_1/5_4pretrain_model_predict.pth')

# キー名の修正
new_state_dict = {}
for key, value in state_dict.items():
    new_key = key.replace("weights_", "weights.")  # キー名の変更
    new_state_dict[new_key] = value

# 修正済みの重みをモデルにロード
model.load_state_dict(new_state_dict, strict=True)
model.to(device)
# Out:
# 8
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 41
#      38     new_state_dict[new_key] = value
#      40 # 修正済みの重みをモデルにロード
# ---> 41 model.load_state_dict(new_state_dict, strict=True)
#      42 model.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LinearAttentionTransformerLM:
# 	Unexpected key(s) in state_dict: "out.weight", "out.bias", "predict.weight", "predict.bias".

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=8, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_pamap_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_129429/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 1.5904, valid Loss: 1.3779586404561996, Accuracy: 41.29%, Val Accuracy: 48.80%
# Epoch 2/100, Loss: 1.2720, valid Loss: 1.2661031633615494, Accuracy: 53.16%, Val Accuracy: 51.63%
# Epoch 3/100, Loss: 1.2127, valid Loss: 1.132058098912239, Accuracy: 54.03%, Val Accuracy: 59.26%
# Epoch 4/100, Loss: 1.1024, valid Loss: 1.0675875321030617, Accuracy: 58.50%, Val Accuracy: 63.83%
# Epoch 5/100, Loss: 1.0440, valid Loss: 1.028952307999134, Accuracy: 61.76%, Val Accuracy: 62.96%
# Epoch 6/100, Loss: 1.0279, valid Loss: 1.1275614276528358, Accuracy: 60.95%, Val Accuracy: 62.09%
# Epoch 7/100, Loss: 1.0037, valid Loss: 1.2213087305426598, Accuracy: 62.91%, Val Accuracy: 57.73%
# Epoch 8/100, Loss: 0.9301, valid Loss: 1.0040549635887146, Accuracy: 65.80%, Val Accuracy: 64.05%
# Epoch 9/100, Loss: 0.9498, valid Loss: 0.9988886192440987, Accuracy: 64.16%, Val Accuracy: 64.27%
# Epoch 10/100, Loss: 0.9106, valid Loss: 0.9464268684387207, Accuracy: 67.05%, Val Accuracy: 69.28%
# Epoch 11/100, Loss: 0.8560, valid Loss: 1.1018670350313187, Accuracy: 67.70%, Val Accuracy: 57.95%
# Epoch 12/100, Loss: 0.8075, valid Loss: 1.036151148378849, Accuracy: 69.99%, Val Accuracy: 64.49%
# Epoch 13/100, Loss: 0.7339, valid Loss: 1.1542337238788605, Accuracy: 73.47%, Val Accuracy: 60.78%
# Epoch 14/100, Loss: 0.7471, valid Loss: 1.0277512893080711, Accuracy: 72.60%, Val Accuracy: 63.83%
# Epoch 15/100, Loss: 0.7106, valid Loss: 0.8737024739384651, Accuracy: 73.69%, Val Accuracy: 69.72%
# Epoch 16/100, Loss: 0.6357, valid Loss: 0.865260437130928, Accuracy: 77.56%, Val Accuracy: 70.59%
# Epoch 17/100, Loss: 0.5846, valid Loss: 0.8356077969074249, Accuracy: 79.14%, Val Accuracy: 70.59%
# Epoch 18/100, Loss: 0.5894, valid Loss: 0.9290450364351273, Accuracy: 78.27%, Val Accuracy: 67.54%
# Epoch 19/100, Loss: 0.5694, valid Loss: 0.7928127571940422, Accuracy: 79.30%, Val Accuracy: 74.07%
# Epoch 20/100, Loss: 0.4719, valid Loss: 0.8377875089645386, Accuracy: 83.77%, Val Accuracy: 74.95%
# Epoch 21/100, Loss: 0.4305, valid Loss: 0.7801985815167427, Accuracy: 85.08%, Val Accuracy: 75.16%
# Epoch 22/100, Loss: 0.4032, valid Loss: 0.9454385861754417, Accuracy: 86.33%, Val Accuracy: 71.46%
# Epoch 23/100, Loss: 0.4156, valid Loss: 0.8904881551861763, Accuracy: 85.57%, Val Accuracy: 70.59%
# Epoch 24/100, Loss: 0.3351, valid Loss: 0.7949957400560379, Accuracy: 88.02%, Val Accuracy: 78.65%
# Epoch 25/100, Loss: 0.3013, valid Loss: 0.7890773490071297, Accuracy: 89.27%, Val Accuracy: 78.65%
# Epoch 26/100, Loss: 0.2775, valid Loss: 0.8215880393981934, Accuracy: 90.52%, Val Accuracy: 77.12%
# Epoch 27/100, Loss: 0.2647, valid Loss: 1.0114680379629135, Accuracy: 91.72%, Val Accuracy: 70.15%
# Epoch 28/100, Loss: 0.3332, valid Loss: 0.8824285119771957, Accuracy: 88.40%, Val Accuracy: 73.86%
# Epoch 29/100, Loss: 0.2472, valid Loss: 0.8228876814246178, Accuracy: 91.94%, Val Accuracy: 77.56%
# Epoch 30/100, Loss: 0.2163, valid Loss: 0.8492105454206467, Accuracy: 93.25%, Val Accuracy: 78.65%
# Epoch 31/100, Loss: 0.2477, valid Loss: 0.8797983266413212, Accuracy: 91.94%, Val Accuracy: 74.95%
# Epoch 32/100, Loss: 0.1875, valid Loss: 0.8313215598464012, Accuracy: 94.06%, Val Accuracy: 75.60%
# Epoch 33/100, Loss: 0.1733, valid Loss: 0.847869262099266, Accuracy: 94.72%, Val Accuracy: 79.96%
# Epoch 34/100, Loss: 0.1830, valid Loss: 0.9828610122203827, Accuracy: 94.23%, Val Accuracy: 74.29%
# Epoch 35/100, Loss: 0.1934, valid Loss: 0.9592162817716599, Accuracy: 93.68%, Val Accuracy: 75.38%
# Epoch 36/100, Loss: 0.1644, valid Loss: 0.8793168440461159, Accuracy: 94.88%, Val Accuracy: 78.43%
# Epoch 37/100, Loss: 0.1117, valid Loss: 0.9388573542237282, Accuracy: 97.17%, Val Accuracy: 77.12%
# Epoch 38/100, Loss: 0.1168, valid Loss: 0.9573073461651802, Accuracy: 96.41%, Val Accuracy: 74.95%
# Epoch 39/100, Loss: 0.0848, valid Loss: 0.9055002555251122, Accuracy: 97.55%, Val Accuracy: 78.87%
# Epoch 40/100, Loss: 0.0809, valid Loss: 1.0482774004340172, Accuracy: 97.39%, Val Accuracy: 73.86%
# Epoch 41/100, Loss: 0.1178, valid Loss: 1.000146932899952, Accuracy: 96.02%, Val Accuracy: 78.00%
# Epoch 42/100, Loss: 0.1399, valid Loss: 1.1639045402407646, Accuracy: 95.59%, Val Accuracy: 73.64%
# Epoch 43/100, Loss: 0.1504, valid Loss: 0.9862949326634407, Accuracy: 94.93%, Val Accuracy: 78.00%
# Epoch 44/100, Loss: 0.1097, valid Loss: 1.102563388645649, Accuracy: 96.79%, Val Accuracy: 73.42%
# Epoch 45/100, Loss: 0.0890, valid Loss: 1.0812851190567017, Accuracy: 97.49%, Val Accuracy: 76.03%
# Epoch 46/100, Loss: 0.1055, valid Loss: 1.1831953525543213, Accuracy: 96.57%, Val Accuracy: 71.68%
# Epoch 47/100, Loss: 0.1066, valid Loss: 1.090732529759407, Accuracy: 95.97%, Val Accuracy: 76.69%
# Epoch 48/100, Loss: 0.0656, valid Loss: 1.0488687753677368, Accuracy: 98.09%, Val Accuracy: 79.30%
# Epoch 49/100, Loss: 0.0614, valid Loss: 1.1145093068480492, Accuracy: 98.09%, Val Accuracy: 77.78%
# Epoch 50/100, Loss: 0.0601, valid Loss: 1.1100575476884842, Accuracy: 98.26%, Val Accuracy: 77.12%
# Epoch 51/100, Loss: 0.0733, valid Loss: 1.1153703108429909, Accuracy: 97.88%, Val Accuracy: 74.51%
# Epoch 52/100, Loss: 0.1762, valid Loss: 1.0897193029522896, Accuracy: 94.83%, Val Accuracy: 75.38%
# Epoch 53/100, Loss: 0.1089, valid Loss: 1.0879678800702095, Accuracy: 96.19%, Val Accuracy: 77.34%
# Epoch 54/100, Loss: 0.0822, valid Loss: 0.9489835277199745, Accuracy: 97.49%, Val Accuracy: 78.00%
# Epoch 55/100, Loss: 0.0692, valid Loss: 1.086251012980938, Accuracy: 97.88%, Val Accuracy: 77.56%
# Epoch 56/100, Loss: 0.0603, valid Loss: 1.0882753655314445, Accuracy: 98.26%, Val Accuracy: 78.00%
# Epoch 57/100, Loss: 0.1212, valid Loss: 1.4212061613798141, Accuracy: 96.19%, Val Accuracy: 69.50%
# Epoch 58/100, Loss: 0.1719, valid Loss: 1.0167224779725075, Accuracy: 94.17%, Val Accuracy: 77.34%
# Epoch 59/100, Loss: 0.0765, valid Loss: 1.1121187880635262, Accuracy: 97.88%, Val Accuracy: 79.52%
# Epoch 60/100, Loss: 0.0556, valid Loss: 1.079783357679844, Accuracy: 98.20%, Val Accuracy: 79.52%
# Epoch 61/100, Loss: 0.0572, valid Loss: 1.1737610027194023, Accuracy: 97.88%, Val Accuracy: 79.30%
# Epoch 62/100, Loss: 0.0495, valid Loss: 1.136440359055996, Accuracy: 98.64%, Val Accuracy: 78.43%
# Epoch 63/100, Loss: 0.0300, valid Loss: 1.176409937441349, Accuracy: 99.29%, Val Accuracy: 78.21%
# Epoch 64/100, Loss: 0.0394, valid Loss: 1.2222473919391632, Accuracy: 98.69%, Val Accuracy: 76.69%
# Epoch 65/100, Loss: 0.0363, valid Loss: 1.2110620215535164, Accuracy: 98.91%, Val Accuracy: 76.47%
# Epoch 66/100, Loss: 0.0296, valid Loss: 1.1442297920584679, Accuracy: 99.07%, Val Accuracy: 77.78%
# Epoch 67/100, Loss: 0.0247, valid Loss: 1.1630130931735039, Accuracy: 99.24%, Val Accuracy: 78.43%
# Epoch 68/100, Loss: 0.0314, valid Loss: 1.193882830440998, Accuracy: 98.97%, Val Accuracy: 77.78%
# Epoch 69/100, Loss: 0.0354, valid Loss: 1.2085720971226692, Accuracy: 99.07%, Val Accuracy: 77.34%
# Epoch 70/100, Loss: 0.0478, valid Loss: 1.2407780066132545, Accuracy: 98.47%, Val Accuracy: 76.03%
# Epoch 71/100, Loss: 0.0389, valid Loss: 1.267655685544014, Accuracy: 98.75%, Val Accuracy: 78.43%
# Epoch 72/100, Loss: 0.0419, valid Loss: 1.2291389480233192, Accuracy: 98.64%, Val Accuracy: 78.21%
# Epoch 73/100, Loss: 0.1399, valid Loss: 1.2191126495599747, Accuracy: 95.75%, Val Accuracy: 75.60%
# Epoch 74/100, Loss: 0.2673, valid Loss: 1.085457168519497, Accuracy: 91.67%, Val Accuracy: 74.95%
# Epoch 75/100, Loss: 0.0850, valid Loss: 1.142156906425953, Accuracy: 97.11%, Val Accuracy: 75.60%
# Epoch 76/100, Loss: 0.0507, valid Loss: 1.235862985253334, Accuracy: 98.58%, Val Accuracy: 74.73%
# Epoch 77/100, Loss: 0.0650, valid Loss: 1.2200875580310822, Accuracy: 98.04%, Val Accuracy: 75.38%
# Epoch 78/100, Loss: 0.0452, valid Loss: 1.1731276884675026, Accuracy: 98.75%, Val Accuracy: 77.78%
# Epoch 79/100, Loss: 0.0283, valid Loss: 1.3173251897096634, Accuracy: 99.46%, Val Accuracy: 77.56%
# Epoch 80/100, Loss: 0.0363, valid Loss: 1.2114174365997314, Accuracy: 98.91%, Val Accuracy: 76.47%
# Epoch 81/100, Loss: 0.0802, valid Loss: 1.3809096962213516, Accuracy: 97.44%, Val Accuracy: 72.77%
# Epoch 82/100, Loss: 0.1362, valid Loss: 1.1815335676074028, Accuracy: 95.53%, Val Accuracy: 76.47%
# Epoch 83/100, Loss: 0.0798, valid Loss: 1.2538717836141586, Accuracy: 97.00%, Val Accuracy: 72.77%
# Epoch 84/100, Loss: 0.0649, valid Loss: 1.1072015762329102, Accuracy: 98.04%, Val Accuracy: 77.34%
# Epoch 85/100, Loss: 0.1278, valid Loss: 1.3391262218356133, Accuracy: 95.64%, Val Accuracy: 72.33%
# Epoch 86/100, Loss: 0.1059, valid Loss: 1.2555645853281021, Accuracy: 96.62%, Val Accuracy: 76.03%
# Epoch 87/100, Loss: 0.0780, valid Loss: 1.403512865304947, Accuracy: 97.28%, Val Accuracy: 74.07%
# Epoch 88/100, Loss: 0.0446, valid Loss: 1.1329220831394196, Accuracy: 98.80%, Val Accuracy: 79.52%
# Epoch 89/100, Loss: 0.0253, valid Loss: 1.1813066080212593, Accuracy: 99.35%, Val Accuracy: 79.30%
# Epoch 90/100, Loss: 0.0223, valid Loss: 1.259484276175499, Accuracy: 99.46%, Val Accuracy: 75.60%
# Epoch 91/100, Loss: 0.0335, valid Loss: 1.2915372550487518, Accuracy: 99.02%, Val Accuracy: 77.56%
# Epoch 92/100, Loss: 0.0240, valid Loss: 1.2695603519678116, Accuracy: 99.35%, Val Accuracy: 76.03%
# Epoch 93/100, Loss: 0.0323, valid Loss: 1.2420627623796463, Accuracy: 99.13%, Val Accuracy: 79.52%
# Epoch 94/100, Loss: 0.0266, valid Loss: 1.3115814626216888, Accuracy: 99.29%, Val Accuracy: 77.56%
# Epoch 95/100, Loss: 0.0173, valid Loss: 1.2858268916606903, Accuracy: 99.40%, Val Accuracy: 78.43%
# Epoch 96/100, Loss: 0.0220, valid Loss: 1.2976315021514893, Accuracy: 99.35%, Val Accuracy: 78.65%
# Epoch 97/100, Loss: 0.0315, valid Loss: 1.353887900710106, Accuracy: 98.97%, Val Accuracy: 77.12%
# Epoch 98/100, Loss: 0.0427, valid Loss: 1.278574526309967, Accuracy: 98.31%, Val Accuracy: 75.16%
# Epoch 99/100, Loss: 0.0289, valid Loss: 1.3800063133239746, Accuracy: 99.02%, Val Accuracy: 76.91%
# Epoch 100/100, Loss: 0.0148, valid Loss: 1.3286217227578163, Accuracy: 99.67%, Val Accuracy: 76.69%
# Best model reloaded with valid loss:  0.7801985815167427   time: 21

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
ax.set_ylim(0.0, 2.5)
ax2.set_ylim(0.0, 2.5)

# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_129429/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 72.125%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.912     0.943     0.927        88
#            1      0.859     0.744     0.797        82
#            2      0.595     0.725     0.654        69
#            3      0.765     0.785     0.775        79
#            4      0.540     0.491     0.514        55
#            5      0.714     0.288     0.411        52
#            6      0.570     0.742     0.645        66
#            7      0.744     0.807     0.775        83
#
#     accuracy                          0.721       574
#    macro avg      0.713     0.691     0.687       574
# weighted avg      0.729     0.721     0.714       574

# %%
val_mean = sum(validation_losses)/100
val_max = max(validation_losses)
val_min = min(validation_losses)

first = validation_losses[0]
end = validation_losses[99]
print("mean  ",val_mean)
print("max   ", val_max)
print("min   ", val_min)
print("first ", first)
print("end   ", end)
# Out:
# mean   1.0987764574214816
# max    1.4212061613798141
# min    0.7801985815167427
# first  1.3779586404561996
# end    1.3286217227578163
