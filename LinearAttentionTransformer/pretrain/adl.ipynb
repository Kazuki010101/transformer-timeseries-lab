# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset

# from transformers import TrainingArguments, Trainer

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformer
from linear_attention_transformer.linear_attention_transformer import LinearAttentionTransformerLM

from linear_attention_transformer.autoregressive_wrapper import AutoregressiveWrapper
from linear_attention_transformer.autopadder import Autopadder
# Grab a GPU if there is one
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using {} device: {}".format(device, torch.cuda.current_device()))
else:
    device = torch.device("cpu")
    print("Using {}".format(device))
# Out:
# Using cuda device: 0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

fold_pamap = "../down_stream_dataset/adl_dataset/"
train_xyz = np.load(f"{fold_pamap}x_train.npy")
valid_xyz = np.load(f"{fold_pamap}x_valid.npy")
test_xyz = np.load(f"{fold_pamap}x_test.npy")
train_label = np.load(f"{fold_pamap}y_train.npy")
valid_label = np.load(f"{fold_pamap}y_valid.npy")
test_label = np.load(f"{fold_pamap}y_test.npy")

# データの形を確認
print(f"Train data shape: {train_xyz.shape}, Train label shape: {train_label.shape}")
print(f"Valid data shape: {valid_xyz.shape}, Valid label shape: {valid_label.shape}")
print(f"Test data shape: {test_xyz.shape}, Test label shape: {test_label.shape}")

# 各データセットを個別に標準化
scaler_train = StandardScaler()
scaler_valid = StandardScaler()
scaler_test = StandardScaler()

# train_xyz の標準化
train_xyz_reshaped = train_xyz.reshape(-1, train_xyz.shape[-1])  # 2Dに変換
scaled_train_xyz = scaler_train.fit_transform(train_xyz_reshaped)  # 標準化
scaled_train_xyz = scaled_train_xyz.reshape(train_xyz.shape)  # 元の形に戻す

# valid_xyz の標準化
valid_xyz_reshaped = valid_xyz.reshape(-1, valid_xyz.shape[-1])  # 2Dに変換
scaled_valid_xyz = scaler_valid.fit_transform(valid_xyz_reshaped)  # 標準化
scaled_valid_xyz = scaled_valid_xyz.reshape(valid_xyz.shape)  # 元の形に戻す

# test_xyz の標準化
test_xyz_reshaped = test_xyz.reshape(-1, test_xyz.shape[-1])  # 2Dに変換
scaled_test_xyz = scaler_test.fit_transform(test_xyz_reshaped)  # 標準化
scaled_test_xyz = scaled_test_xyz.reshape(test_xyz.shape)  # 元の形に戻す

# 各データセットの形状を再確認
print(f"Scaled Train data shape: {scaled_train_xyz.shape}")
print(f"Scaled Valid data shape: {scaled_valid_xyz.shape}")
print(f"Scaled Test data shape: {scaled_test_xyz.shape}")
# Out:
# Train data shape: (406, 3, 300), Train label shape: (406,)
# Valid data shape: (102, 3, 300), Valid label shape: (102,)
# Test data shape: (127, 3, 300), Test label shape: (127,)
# Scaled Train data shape: (406, 3, 300)
# Scaled Valid data shape: (102, 3, 300)
# Scaled Test data shape: (127, 3, 300)

# %%
print(pd.Series(train_label).value_counts())
print(pd.Series(test_label).value_counts())
print(pd.Series(valid_label).value_counts())
# Out:
# 4    186
# 1     62
# 2     58
# 3     54
# 0     46
# dtype: int64
# 4    51
# 1    25
# 3    22
# 2    19
# 0    10
# dtype: int64
# 4    42
# 1    18
# 3    17
# 2    15
# 0    10
# dtype: int64

# %%
train_xyz = scaled_train_xyz
valid_xyz = scaled_valid_xyz
test_xyz = scaled_test_xyz

# %%
num_classes = len(np.unique(train_label))  # クラス数
print(num_classes)
dim = 768
depth = 8
heads = 12
dropout = 0.1

class Config:
    def __init__(self, dim, depth, max_seq_len, heads, causal):
        self.dim = dim
        self.depth = depth
        self.max_seq_len = max_seq_len
        self.heads = heads
        self.causal = causal

config = Config(
    dim=768,
    depth=8,
    max_seq_len=300,
    heads=12,
    causal=True
)

# `config` の属性を展開して渡す
model = LinearAttentionTransformerLM(
    dim=config.dim,
    depth=config.depth,
    max_seq_len=config.max_seq_len,
    heads=config.heads,
    causal=config.causal
)
state_dict = torch.load('path/pretrained_1/5_4pretrain_model_predict.pth')

# キー名の修正
new_state_dict = {}
for key, value in state_dict.items():
    new_key = key.replace("weights_", "weights.")  # キー名の変更
    new_state_dict[new_key] = value

# 修正済みの重みをモデルにロード
model.load_state_dict(new_state_dict, strict=True)
model.to(device)
# Out:
# 5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 41
#      38     new_state_dict[new_key] = value
#      40 # 修正済みの重みをモデルにロード
# ---> 41 model.load_state_dict(new_state_dict, strict=True)
#      42 model.to(device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LinearAttentionTransformerLM:
# 	Unexpected key(s) in state_dict: "norm.weight", "norm.bias", "out.weight", "out.bias", "predict.weight", "predict.bias".

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class ClassificationDataset(Dataset):
    def __init__(self, data, labels):
        super().__init__()
        self._data = data 
        self._labels = labels  

    def __len__(self):
        return len(self._labels)

    def __getitem__(self, idx):
        return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)

# %%
train_label = torch.tensor(train_label, dtype=torch.long)
test_label = torch.tensor(test_label, dtype=torch.long)
valid_label = torch.tensor(valid_label, dtype=torch.long)

train_label = train_label - train_label.min()
test_label = test_label - test_label.min()
valid_label = valid_label - valid_label.min()

# %%
train_dataset = ClassificationDataset(train_xyz, train_label)
test_dataset = ClassificationDataset(test_xyz, test_label)
valid_dataset = ClassificationDataset(valid_xyz, valid_label)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class TrainModel(LinearAttentionTransformerLM):
    def __init__(self, num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True):
        # 親クラスの初期化に必要な引数を渡す
        super().__init__(dim=dim, depth=depth, max_seq_len=max_seq_len, heads=heads, causal=causal)
        self.fc1 = nn.Linear(768 * 3, 768)
        self.fc2 = nn.Linear(768, num_classes)

    def forward(self, x):
        features = super().forward(x)  
        out_x = features[:, 0, :]
        out_y = features[:, 1, :]
        out_z = features[:, 2, :]
        combined = torch.cat((out_x, out_y, out_z), dim=1)
        output = F.relu(self.fc1(combined))
        output = self.fc2(output)
        return output
# モデルの作成例
train_model = TrainModel(num_classes=num_classes, dim=768, depth=8, max_seq_len=300, heads=12, causal=True)
train_model.to(device)
# Out:
# TrainModel(
#   (token_emb): Linear(in_features=300, out_features=768, bias=True)
#   (pos_emb): AxialPositionalEmbedding(
#     (weights): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 1x3x1x768 (GPU 0)]
#         (1): Parameter containing: [torch.float32 of size 1x1x128x768 (GPU 0)]
#     )
#   )
#   (transformer): LinearAttentionTransformer(
#     (layers): SequentialSequence(
#       (layers): ModuleList(
#         (0): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (6): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (7): ModuleList(
#           (0): PreNorm(
#             (fn): SelfAttention(
#               (local_attn): LocalAttention(
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (to_q): Linear(in_features=768, out_features=768, bias=False)
#               (to_k): Linear(in_features=768, out_features=768, bias=False)
#               (to_v): Linear(in_features=768, out_features=768, bias=False)
#               (to_out): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): PreNorm(
#             (fn): Chunk(
#               (fn): FeedForward(
#                 (w1): Linear(in_features=768, out_features=3072, bias=True)
#                 (act): GELU(approximate='none')
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (w2): Linear(in_features=3072, out_features=768, bias=True)
#               )
#             )
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#   )
#   (fc1): Linear(in_features=2304, out_features=768, bias=True)
#   (fc2): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(train_model.parameters(), lr=1e-4)

num_epochs = 100

train_loss = []
validation_losses = []
best_valid_loss = float('inf')
best_model_path = 'path/best_model_adl_768.pth'

time_epoch = 0

for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    val_correct = 0
    val_total = 0
    total_val_loss = 0
    
    train_model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # 順伝播
        outputs = train_model(inputs)
        loss = criterion(outputs, labels)
        # 逆伝播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 統計
        total_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    train_loss.append(total_loss / len(train_loader))
    
    train_model.eval()  # Set model to evaluation mode
    
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient computation
        for val_inputs, val_targets in val_loader:
            val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)
            val_outputs = train_model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            total_val_loss += val_loss.item()
            
            # 統計
            _, val_predicted = torch.max(val_outputs, 1)
            val_total += val_targets.size(0)
            val_correct += (val_predicted == val_targets).sum().item()
            
        if total_val_loss < best_valid_loss:
            best_valid_loss = total_val_loss
            torch.save(train_model.state_dict(), best_model_path)
            time_epoch = epoch + 1
    validation_losses.append(total_val_loss / len(val_loader))
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(train_loader):.4f}, valid Loss: {total_val_loss / len(val_loader)}, Accuracy: {100 * correct / total:.2f}%, Val Accuracy: {100 * val_correct / val_total:.2f}%")
train_model.load_state_dict(torch.load(best_model_path))
print("Best model reloaded with valid loss: ", best_valid_loss/ len(val_loader), f"  time: {time_epoch}")
# Out:
# /tmp/ipykernel_93223/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Epoch 1/100, Loss: 1.9004, valid Loss: 1.0255758464336395, Accuracy: 32.02%, Val Accuracy: 59.80%
# Epoch 2/100, Loss: 0.9239, valid Loss: 0.7781774699687958, Accuracy: 65.27%, Val Accuracy: 66.67%
# Epoch 3/100, Loss: 0.6698, valid Loss: 0.9049516022205353, Accuracy: 74.38%, Val Accuracy: 75.49%
# Epoch 4/100, Loss: 0.7069, valid Loss: 0.6426544189453125, Accuracy: 76.11%, Val Accuracy: 77.45%
# Epoch 5/100, Loss: 0.5646, valid Loss: 0.5268474221229553, Accuracy: 79.56%, Val Accuracy: 80.39%
# Epoch 6/100, Loss: 0.4582, valid Loss: 0.4938208609819412, Accuracy: 83.25%, Val Accuracy: 82.35%
# Epoch 7/100, Loss: 0.4693, valid Loss: 0.6376226842403412, Accuracy: 84.24%, Val Accuracy: 52.94%
# Epoch 8/100, Loss: 0.4810, valid Loss: 0.544695720076561, Accuracy: 82.27%, Val Accuracy: 81.37%
# Epoch 9/100, Loss: 0.3968, valid Loss: 0.5907057225704193, Accuracy: 83.74%, Val Accuracy: 79.41%
# Epoch 10/100, Loss: 0.3982, valid Loss: 0.49220700562000275, Accuracy: 85.47%, Val Accuracy: 83.33%
# Epoch 11/100, Loss: 0.3477, valid Loss: 0.5160042196512222, Accuracy: 86.95%, Val Accuracy: 79.41%
# Epoch 12/100, Loss: 0.3329, valid Loss: 0.48179659247398376, Accuracy: 84.24%, Val Accuracy: 81.37%
# Epoch 13/100, Loss: 0.3733, valid Loss: 0.5594605505466461, Accuracy: 87.19%, Val Accuracy: 76.47%
# Epoch 14/100, Loss: 0.3920, valid Loss: 0.5933348834514618, Accuracy: 86.21%, Val Accuracy: 81.37%
# Epoch 15/100, Loss: 0.3819, valid Loss: 0.6776270568370819, Accuracy: 85.71%, Val Accuracy: 71.57%
# Epoch 16/100, Loss: 0.3769, valid Loss: 0.466926246881485, Accuracy: 85.22%, Val Accuracy: 83.33%
# Epoch 17/100, Loss: 0.3070, valid Loss: 0.5221512913703918, Accuracy: 89.90%, Val Accuracy: 78.43%
# Epoch 18/100, Loss: 0.3236, valid Loss: 0.43622809648513794, Accuracy: 86.70%, Val Accuracy: 82.35%
# Epoch 19/100, Loss: 0.2613, valid Loss: 0.4447814077138901, Accuracy: 92.36%, Val Accuracy: 81.37%
# Epoch 20/100, Loss: 0.2616, valid Loss: 0.4204227030277252, Accuracy: 90.64%, Val Accuracy: 81.37%
# Epoch 21/100, Loss: 0.2400, valid Loss: 0.46052423119544983, Accuracy: 89.41%, Val Accuracy: 85.29%
# Epoch 22/100, Loss: 0.2557, valid Loss: 0.4103687107563019, Accuracy: 90.15%, Val Accuracy: 84.31%
# Epoch 23/100, Loss: 0.2919, valid Loss: 0.43462519347667694, Accuracy: 89.90%, Val Accuracy: 83.33%
# Epoch 24/100, Loss: 0.2741, valid Loss: 0.5188631266355515, Accuracy: 90.39%, Val Accuracy: 79.41%
# Epoch 25/100, Loss: 0.2965, valid Loss: 0.47744596004486084, Accuracy: 89.90%, Val Accuracy: 83.33%
# Epoch 26/100, Loss: 0.3047, valid Loss: 0.5604345798492432, Accuracy: 85.71%, Val Accuracy: 81.37%
# Epoch 27/100, Loss: 0.2662, valid Loss: 0.47232167422771454, Accuracy: 91.63%, Val Accuracy: 84.31%
# Epoch 28/100, Loss: 0.2272, valid Loss: 0.4110103249549866, Accuracy: 89.66%, Val Accuracy: 84.31%
# Epoch 29/100, Loss: 0.2182, valid Loss: 0.42164528369903564, Accuracy: 92.86%, Val Accuracy: 83.33%
# Epoch 30/100, Loss: 0.1880, valid Loss: 0.40073244273662567, Accuracy: 93.35%, Val Accuracy: 85.29%
# Epoch 31/100, Loss: 0.1735, valid Loss: 0.45537538826465607, Accuracy: 94.09%, Val Accuracy: 85.29%
# Epoch 32/100, Loss: 0.1505, valid Loss: 0.4192253202199936, Accuracy: 94.33%, Val Accuracy: 88.24%
# Epoch 33/100, Loss: 0.1692, valid Loss: 0.8645995259284973, Accuracy: 95.07%, Val Accuracy: 64.71%
# Epoch 34/100, Loss: 0.2759, valid Loss: 0.6662504374980927, Accuracy: 89.90%, Val Accuracy: 63.73%
# Epoch 35/100, Loss: 0.3893, valid Loss: 0.691122442483902, Accuracy: 85.96%, Val Accuracy: 74.51%
# Epoch 36/100, Loss: 0.2786, valid Loss: 0.7168863117694855, Accuracy: 90.15%, Val Accuracy: 79.41%
# Epoch 37/100, Loss: 0.2433, valid Loss: 0.49655070900917053, Accuracy: 89.90%, Val Accuracy: 85.29%
# Epoch 38/100, Loss: 0.2089, valid Loss: 0.44700536131858826, Accuracy: 92.86%, Val Accuracy: 88.24%
# Epoch 39/100, Loss: 0.2056, valid Loss: 0.4774307757616043, Accuracy: 93.84%, Val Accuracy: 83.33%
# Epoch 40/100, Loss: 0.2771, valid Loss: 0.5009628683328629, Accuracy: 88.92%, Val Accuracy: 83.33%
# Epoch 41/100, Loss: 0.2999, valid Loss: 0.5065781027078629, Accuracy: 90.15%, Val Accuracy: 82.35%
# Epoch 42/100, Loss: 0.2877, valid Loss: 0.4426884204149246, Accuracy: 89.41%, Val Accuracy: 84.31%
# Epoch 43/100, Loss: 0.2784, valid Loss: 0.40592895448207855, Accuracy: 90.15%, Val Accuracy: 86.27%
# Epoch 44/100, Loss: 0.1828, valid Loss: 0.44957855343818665, Accuracy: 93.84%, Val Accuracy: 82.35%
# Epoch 45/100, Loss: 0.1862, valid Loss: 0.5266458690166473, Accuracy: 93.84%, Val Accuracy: 80.39%
# Epoch 46/100, Loss: 0.2081, valid Loss: 0.39116330444812775, Accuracy: 91.13%, Val Accuracy: 87.25%
# Epoch 47/100, Loss: 0.1451, valid Loss: 0.4651467502117157, Accuracy: 94.58%, Val Accuracy: 86.27%
# Epoch 48/100, Loss: 0.1805, valid Loss: 0.46224771440029144, Accuracy: 93.84%, Val Accuracy: 84.31%
# Epoch 49/100, Loss: 0.1672, valid Loss: 0.36399517953395844, Accuracy: 94.33%, Val Accuracy: 86.27%
# Epoch 50/100, Loss: 0.1679, valid Loss: 0.43313902616500854, Accuracy: 94.58%, Val Accuracy: 86.27%
# Epoch 51/100, Loss: 0.1446, valid Loss: 0.4917568117380142, Accuracy: 96.55%, Val Accuracy: 81.37%
# Epoch 52/100, Loss: 0.1471, valid Loss: 0.4590775817632675, Accuracy: 94.58%, Val Accuracy: 84.31%
# Epoch 53/100, Loss: 0.1342, valid Loss: 0.4914015680551529, Accuracy: 95.32%, Val Accuracy: 85.29%
# Epoch 54/100, Loss: 0.2076, valid Loss: 0.4276856929063797, Accuracy: 93.84%, Val Accuracy: 88.24%
# Epoch 55/100, Loss: 0.1257, valid Loss: 0.37029796838760376, Accuracy: 94.83%, Val Accuracy: 87.25%
# Epoch 56/100, Loss: 0.1396, valid Loss: 0.40073733031749725, Accuracy: 95.32%, Val Accuracy: 89.22%
# Epoch 57/100, Loss: 0.1117, valid Loss: 0.39863020181655884, Accuracy: 97.29%, Val Accuracy: 89.22%
# Epoch 58/100, Loss: 0.1107, valid Loss: 0.44540706276893616, Accuracy: 97.04%, Val Accuracy: 89.22%
# Epoch 59/100, Loss: 0.1019, valid Loss: 0.4813792109489441, Accuracy: 97.04%, Val Accuracy: 82.35%
# Epoch 60/100, Loss: 0.1381, valid Loss: 0.4221538305282593, Accuracy: 95.32%, Val Accuracy: 90.20%
# Epoch 61/100, Loss: 0.2651, valid Loss: 0.5845488905906677, Accuracy: 92.12%, Val Accuracy: 86.27%
# Epoch 62/100, Loss: 0.2118, valid Loss: 0.527610570192337, Accuracy: 91.38%, Val Accuracy: 85.29%
# Epoch 63/100, Loss: 0.2334, valid Loss: 0.5327295958995819, Accuracy: 90.89%, Val Accuracy: 83.33%
# Epoch 64/100, Loss: 0.2428, valid Loss: 0.475286602973938, Accuracy: 89.16%, Val Accuracy: 85.29%
# Epoch 65/100, Loss: 0.2307, valid Loss: 0.4644770473241806, Accuracy: 91.63%, Val Accuracy: 84.31%
# Epoch 66/100, Loss: 0.2204, valid Loss: 0.49982623755931854, Accuracy: 92.12%, Val Accuracy: 83.33%
# Epoch 67/100, Loss: 0.1827, valid Loss: 0.4920952767133713, Accuracy: 93.10%, Val Accuracy: 82.35%
# Epoch 68/100, Loss: 0.1577, valid Loss: 0.40638674795627594, Accuracy: 94.33%, Val Accuracy: 87.25%
# Epoch 69/100, Loss: 0.1315, valid Loss: 0.4212922155857086, Accuracy: 95.07%, Val Accuracy: 84.31%
# Epoch 70/100, Loss: 0.0795, valid Loss: 0.42969951033592224, Accuracy: 97.29%, Val Accuracy: 86.27%
# Epoch 71/100, Loss: 0.0632, valid Loss: 0.49136437475681305, Accuracy: 97.78%, Val Accuracy: 87.25%
# Epoch 72/100, Loss: 0.0704, valid Loss: 0.4286317229270935, Accuracy: 97.54%, Val Accuracy: 88.24%
# Epoch 73/100, Loss: 0.0593, valid Loss: 0.5499343276023865, Accuracy: 98.28%, Val Accuracy: 88.24%
# Epoch 74/100, Loss: 0.0776, valid Loss: 0.49797962605953217, Accuracy: 97.29%, Val Accuracy: 90.20%
# Epoch 75/100, Loss: 0.0721, valid Loss: 0.5157486647367477, Accuracy: 96.80%, Val Accuracy: 90.20%
# Epoch 76/100, Loss: 0.0598, valid Loss: 0.5853416323661804, Accuracy: 97.78%, Val Accuracy: 85.29%
# Epoch 77/100, Loss: 0.0692, valid Loss: 0.46868616342544556, Accuracy: 97.29%, Val Accuracy: 89.22%
# Epoch 78/100, Loss: 0.0486, valid Loss: 0.5336775183677673, Accuracy: 99.01%, Val Accuracy: 89.22%
# Epoch 79/100, Loss: 0.0679, valid Loss: 0.7278294563293457, Accuracy: 97.29%, Val Accuracy: 82.35%
# Epoch 80/100, Loss: 0.1288, valid Loss: 0.6134540289640427, Accuracy: 96.80%, Val Accuracy: 87.25%
# Epoch 81/100, Loss: 0.0529, valid Loss: 0.5701682865619659, Accuracy: 97.78%, Val Accuracy: 81.37%
# Epoch 82/100, Loss: 0.0556, valid Loss: 0.470076322555542, Accuracy: 98.03%, Val Accuracy: 89.22%
# Epoch 83/100, Loss: 0.0496, valid Loss: 0.48615799844264984, Accuracy: 98.03%, Val Accuracy: 87.25%
# Epoch 84/100, Loss: 0.0605, valid Loss: 0.6102501749992371, Accuracy: 98.52%, Val Accuracy: 84.31%
# Epoch 85/100, Loss: 0.0936, valid Loss: 0.9155252575874329, Accuracy: 97.78%, Val Accuracy: 73.53%
# Epoch 86/100, Loss: 0.0876, valid Loss: 0.6253597885370255, Accuracy: 97.04%, Val Accuracy: 85.29%
# Epoch 87/100, Loss: 0.0700, valid Loss: 0.5965700298547745, Accuracy: 96.80%, Val Accuracy: 89.22%
# Epoch 88/100, Loss: 0.0519, valid Loss: 0.6071589291095734, Accuracy: 98.28%, Val Accuracy: 80.39%
# Epoch 89/100, Loss: 0.0487, valid Loss: 0.6408736407756805, Accuracy: 98.77%, Val Accuracy: 90.20%
# Epoch 90/100, Loss: 0.0772, valid Loss: 0.6062203049659729, Accuracy: 98.03%, Val Accuracy: 83.33%
# Epoch 91/100, Loss: 0.0682, valid Loss: 0.5172897130250931, Accuracy: 97.29%, Val Accuracy: 92.16%
# Epoch 92/100, Loss: 0.0679, valid Loss: 0.5989870727062225, Accuracy: 97.78%, Val Accuracy: 86.27%
# Epoch 93/100, Loss: 0.0641, valid Loss: 0.6276445686817169, Accuracy: 97.54%, Val Accuracy: 86.27%
# Epoch 94/100, Loss: 0.0445, valid Loss: 0.5857198387384415, Accuracy: 98.52%, Val Accuracy: 87.25%
# Epoch 95/100, Loss: 0.0305, valid Loss: 0.6141312271356583, Accuracy: 99.51%, Val Accuracy: 88.24%
# Epoch 96/100, Loss: 0.0201, valid Loss: 0.6204404979944229, Accuracy: 99.51%, Val Accuracy: 88.24%
# Epoch 97/100, Loss: 0.0129, valid Loss: 0.6132341474294662, Accuracy: 99.75%, Val Accuracy: 88.24%
# Epoch 98/100, Loss: 0.0100, valid Loss: 0.6263442486524582, Accuracy: 99.75%, Val Accuracy: 84.31%
# Epoch 99/100, Loss: 0.0071, valid Loss: 0.6760946214199066, Accuracy: 100.00%, Val Accuracy: 83.33%
# Epoch 100/100, Loss: 0.0090, valid Loss: 0.7410828024148941, Accuracy: 99.75%, Val Accuracy: 89.22%
# Best model reloaded with valid loss:  0.36399517953395844   time: 49

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

plt.close('all')
fig, ax = plt.subplots()
ax.plot(train_loss, color='C0', label='train loss')
ax.plot(validation_losses, color='C1', label='valid loss')

ax.set_ylabel('loss (CE)')
ax.set_xlabel('epoch')

# 二軸グラフの追加
ax2 = ax.twinx()
ax2.grid(True)

# 凡例の表示
fig.legend(loc='upper right')
plt.ylim(0.0, 2.50)
# グラフの表示
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_model(model, test_loader, device):
    model.eval()
    test_correct = 0
    test_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    # 小数点3桁で精度表示
    test_accuracy = round(100 * test_correct / test_total, 3)
    print(f"Test Accuracy: {test_accuracy:.3f}%")

    # 分類レポートを小数点3桁で表示
    print("\nClassification Report:")
    report = classification_report(all_labels, all_preds, zero_division=0, digits=3)
    print(report)

    # 混同行列の計算と表示
    conf_matrix = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

    return test_accuracy, all_preds, all_labels


test_accuracy, test_preds, test_labels = evaluate_model(train_model, test_loader, device)
# Out:
# /tmp/ipykernel_93223/3962539304.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(self._data[idx], dtype=torch.float32), torch.tensor(self._labels[idx], dtype=torch.long)
# Test Accuracy: 92.126%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.714     0.500     0.588        10
#            1      0.962     1.000     0.980        25
#            2      0.941     0.842     0.889        19
#            3      1.000     1.000     1.000        22
#            4      0.891     0.961     0.925        51
#
#     accuracy                          0.921       127
#    macro avg      0.902     0.861     0.876       127
# weighted avg      0.917     0.921     0.917       127

# %%
val_mean = sum(validation_losses)/100
val_max = max(validation_losses)
val_min = min(validation_losses)

first = validation_losses[0]
end = validation_losses[99]
print("mean  ",val_mean)
print("max   ", val_max)
print("min   ", val_min)
print("first ", first)
print("end   ", end)
# Out:
# mean   0.5349094128608703
# max    1.0255758464336395
# min    0.36399517953395844
# first  1.0255758464336395
# end    0.7410828024148941
